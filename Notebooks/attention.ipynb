# %%
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow.keras.backend as K
from keras.metrics import MeanIoU
import os
import numpy as np
from sklearn.model_selection import train_test_split
from PIL import Image, ImageOps
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization, MaxPooling2D, Dropout, UpSampling2D, concatenate, Activation, multiply, Reshape,BatchNormalization
from keras.layers import GlobalAveragePooling2D, Reshape
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler,EarlyStopping
# Out:
# 2024-12-24 14:59:18.222399: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-24 14:59:18.222557: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-24 14:59:18.361185: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_data(image_filenames, mask_filenames, image_dir, mask_dir, image_size=(512, 512)):
    image_list, mask_list = [], []
    for img_file, mask_file in zip(image_filenames, mask_filenames):
        if img_file.endswith(".png") and mask_file.endswith(".png"):
            image = cv2.imread(os.path.join(image_dir, img_file), cv2.IMREAD_GRAYSCALE)
            image = cv2.resize(image, image_size)
            image = image / 255.0  # Normalize to [0, 1]
            image = np.expand_dims(image, axis=-1)  # Add channel dimension
            image_list.append(image)
            
            mask = cv2.imread(os.path.join(mask_dir, mask_file), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, image_size)
            mask = mask / 255.0  # Normalize to [0, 1]
            mask = np.expand_dims(mask, axis=-1)  # Add channel dimension
            mask_list.append(mask)
    return np.array(image_list), np.array(mask_list)

# %%
# Define paths to your image and mask directories
image_dir = '/kaggle/input/fives-a-fundus-image/FIVES A Fundus Image Dataset for AI-based Vessel Segmentation/train/Original/'
mask_dir = '/kaggle/input/fives-a-fundus-image/FIVES A Fundus Image Dataset for AI-based Vessel Segmentation/train/Ground truth/'

# Get list of image and mask filenames
image_filenames = os.listdir(image_dir)
mask_filenames = os.listdir(mask_dir)

# Sort filenames to ensure corresponding images and masks match
image_filenames.sort()
mask_filenames.sort()
# Load images and masks
images, masks = load_data(image_filenames, mask_filenames, image_dir, mask_dir)

# %%
# Define paths to your image and mask directories
image_dir = '/kaggle/input/fives-a-fundus-image/FIVES A Fundus Image Dataset for AI-based Vessel Segmentation/test/Original/'
mask_dir = '/kaggle/input/fives-a-fundus-image/FIVES A Fundus Image Dataset for AI-based Vessel Segmentation/test/Ground truth/'

# Get list of image and mask filenames
image_filenames = os.listdir(image_dir)
mask_filenames = os.listdir(mask_dir)

# Sort filenames to ensure corresponding images and masks match
image_filenames.sort()
mask_filenames.sort()
# Load images and masks
Images_test, Masks_test = load_data(image_filenames, mask_filenames, image_dir, mask_dir)

# %%
images =np.array(images)
masks =np.array(masks)
Images_test =np.array(Images_test)
Masks_test =np.array(Masks_test)

images_val, images_test, masks_val, masks_test = train_test_split(Images_test, Masks_test, test_size=0.5, random_state=42)

# Print shapes to verify
print("Training images shape:", images.shape)
print("Training masks shape:", masks.shape)
print("test images shape:", images_test.shape)
print("test masks shape:", masks_test.shape)
print("validation images shape:", images_val.shape)
print("validation masks shape:", masks_val.shape)
# Ensure your images and masks are 4D tensors with consistent shapes

images = tf.expand_dims(images, axis=-1)  # If your images are (batch, height, width)
masks = tf.expand_dims(masks, axis=-1)    # If your masks are (batch, height, width)

images_test = tf.expand_dims(images_test, axis=-1)
masks_test = tf.expand_dims(masks_test, axis=-1)

images_val = tf.expand_dims(images_val, axis=-1)
masks_val = tf.expand_dims(masks_val, axis=-1)
# Out:
# Training images shape: (600, 512, 512, 1)
# Training masks shape: (600, 512, 512, 1)
# test images shape: (100, 512, 512, 1)
# test masks shape: (100, 512, 512, 1)
# validation images shape: (100, 512, 512, 1)
# validation masks shape: (100, 512, 512, 1)

# %%
def dice_loss(y_true, y_pred):
    smooth = 1.0  # To avoid division by zero
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

# Define PSNR metric
def psnr(y_true, y_pred):
    # Ensure y_true and y_pred have the same shape
    y_true = tf.ensure_shape(y_true, y_pred.shape)
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

stop_callback=EarlyStopping(monitor='val_accuracy',restore_best_weights=True,verbose=1 , mode='max',patience=50,start_from_epoch=0)

# Custom SSIM metric
def ssim_metric(y_true, y_pred):
    return tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=1.0))

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout, Conv2DTranspose, BatchNormalization, Activation, Add
from tensorflow.keras.models import Model

# %%
def attention_block(x, g, inter_channels):
    theta_x = tf.keras.layers.Conv2D(inter_channels, (1, 1), padding='same')(x)
    phi_g = tf.keras.layers.Conv2D(inter_channels, (1, 1), padding='same')(g)
    concat = tf.keras.layers.Add()([theta_x, phi_g])
    psi = tf.keras.layers.Activation('relu')(concat)
    psi = tf.keras.layers.Conv2D(1, (1, 1), padding='same')(psi)
    psi = tf.keras.layers.Activation('sigmoid')(psi)
    return tf.keras.layers.Multiply()([x, psi])

def attention_unet(input_shape=(512, 512, 1)):
    inputs = tf.keras.Input(input_shape)
    # Encoder
    c1 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)
    # Bottleneck
    bottleneck = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p1)
    # Decoder
    g = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bottleneck)
    attn = attention_block(c1, g, 32)
    outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(attn)
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
attention = attention_unet(input_shape=(512, 512, 1))

# %%
print("Images shape:", images.shape)  # Should be (batch_size, 512, 512, 1)
print("Masks shape:", masks.shape)    # Should be (batch_size, 512, 512, 1)
# Out:
# Images shape: (600, 512, 512, 1, 1)
# Masks shape: (600, 512, 512, 1, 1)

# %%
# Ensure tensors have the correct shape by removing all unnecessary dimensions first
images = tf.squeeze(images)  # Removes all dimensions of size 1
masks = tf.squeeze(masks)
images_val = tf.squeeze(images_val)
masks_val = tf.squeeze(masks_val)
images_test = tf.squeeze(images_test)
masks_test = tf.squeeze(masks_test)

# Add back the single channel dimension to ensure (batch_size, 512, 512, 1)
images = tf.expand_dims(images, axis=-1)
masks = tf.expand_dims(masks, axis=-1)
images_val = tf.expand_dims(images_val, axis=-1)
masks_val = tf.expand_dims(masks_val, axis=-1)
images_test = tf.expand_dims(images_test, axis=-1)
masks_test = tf.expand_dims(masks_test, axis=-1)

# Verify the new shapes
print("Images shape:", images.shape)  # Should be (batch_size, 512, 512, 1)
print("Masks shape:", masks.shape)    # Should be (batch_size, 512, 512, 1)
# Out:
# Images shape: (600, 512, 512, 1)
# Masks shape: (600, 512, 512, 1)

# %%
attention.compile(optimizer='adam', loss='binary_crossentropy', 
              metrics=['accuracy', tf.keras.metrics.Precision(), MeanIoU(num_classes=2),dice_loss,ssim_metric,psnr])

# %%
history = attention.fit(images,masks,validation_data=(images_val,masks_val), epochs=50, batch_size=1, verbose = 1)
# Out:
# Epoch 1/50
# 2024-12-24 15:02:13.679184: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262144: 1.24674, expected 0.706489
# 2024-12-24 15:02:13.679253: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262145: 2.29621, expected 1.75596
# 2024-12-24 15:02:13.679268: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262146: 2.24082, expected 1.70057
# 2024-12-24 15:02:13.679282: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262147: 1.8087, expected 1.26845
# 2024-12-24 15:02:13.679297: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262148: 2.13502, expected 1.59477
# 2024-12-24 15:02:13.679308: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262149: 2.59674, expected 2.05649
# 2024-12-24 15:02:13.679318: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262150: 2.16053, expected 1.62028
# 2024-12-24 15:02:13.679329: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262151: 2.13737, expected 1.59712
# 2024-12-24 15:02:13.679339: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262152: 2.22161, expected 1.68136
# 2024-12-24 15:02:13.679350: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262153: 1.79817, expected 1.25791
# 2024-12-24 15:02:13.691005: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 15:02:13.691088: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 15:02:13.691104: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 15:02:13.691116: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 15:02:13.691126: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 15:02:13.691146: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-12-24 15:02:13.927245: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262144: 1.24674, expected 0.706489
# 2024-12-24 15:02:13.927304: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262145: 2.29621, expected 1.75596
# 2024-12-24 15:02:13.927322: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262146: 2.24082, expected 1.70057
# 2024-12-24 15:02:13.927335: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262147: 1.8087, expected 1.26845
# 2024-12-24 15:02:13.927347: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262148: 2.13502, expected 1.59477
# 2024-12-24 15:02:13.927358: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262149: 2.59674, expected 2.05649
# 2024-12-24 15:02:13.927368: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262150: 2.16053, expected 1.62028
# 2024-12-24 15:02:13.927379: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262151: 2.13737, expected 1.59712
# 2024-12-24 15:02:13.927389: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262152: 2.22161, expected 1.68136
# 2024-12-24 15:02:13.927400: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262153: 1.79817, expected 1.25791
# 2024-12-24 15:02:13.939116: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 15:02:13.939175: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 15:02:13.939188: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 15:02:13.939200: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 15:02:13.939210: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 15:02:13.939232: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
#   5/600 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - accuracy: 0.9225 - dice_loss: 0.8843 - loss: 0.6760 - mean_io_u: 0.4695 - precision: 4.6598e-04 - psnr: 6.2236 - ssim_metric: 0.0021
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1735052540.169083     105 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 31s 34ms/step - accuracy: 0.9184 - dice_loss: 0.9096 - loss: 0.2964 - mean_io_u: 0.3853 - precision: 4.6598e-04 - psnr: 11.3765 - ssim_metric: 0.1246 - val_accuracy: 0.9237 - val_dice_loss: 0.8848 - val_loss: 0.2367 - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: 12.3102 - val_ssim_metric: 0.2173
# Epoch 2/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9182 - dice_loss: 0.8905 - loss: 0.2367 - mean_io_u: 0.3851 - precision: 0.1620 - psnr: 12.1863 - ssim_metric: 0.2168 - val_accuracy: 0.9254 - val_dice_loss: 0.8177 - val_loss: 0.2026 - val_mean_io_u: 0.4551 - val_precision: 0.6252 - val_psnr: 13.0094 - val_ssim_metric: 0.2457
# Epoch 3/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9213 - dice_loss: 0.7975 - loss: 0.2074 - mean_io_u: 0.3847 - precision: 0.7253 - psnr: 12.7929 - ssim_metric: 0.2518 - val_accuracy: 0.9280 - val_dice_loss: 0.7826 - val_loss: 0.1972 - val_mean_io_u: 0.4551 - val_precision: 0.6853 - val_psnr: 13.2128 - val_ssim_metric: 0.2685
# Epoch 4/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9247 - dice_loss: 0.7579 - loss: 0.2014 - mean_io_u: 0.3845 - precision: 0.7309 - psnr: 12.9537 - ssim_metric: 0.2690 - val_accuracy: 0.9298 - val_dice_loss: 0.7558 - val_loss: 0.1925 - val_mean_io_u: 0.4551 - val_precision: 0.6773 - val_psnr: 13.3218 - val_ssim_metric: 0.2739
# Epoch 5/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9253 - dice_loss: 0.7388 - loss: 0.1986 - mean_io_u: 0.3838 - precision: 0.7493 - psnr: 13.0455 - ssim_metric: 0.2760 - val_accuracy: 0.9290 - val_dice_loss: 0.7707 - val_loss: 0.1925 - val_mean_io_u: 0.4551 - val_precision: 0.7051 - val_psnr: 13.2911 - val_ssim_metric: 0.2763
# Epoch 6/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9265 - dice_loss: 0.7350 - loss: 0.1943 - mean_io_u: 0.3847 - precision: 0.7389 - psnr: 13.0969 - ssim_metric: 0.2768 - val_accuracy: 0.9302 - val_dice_loss: 0.7362 - val_loss: 0.1822 - val_mean_io_u: 0.4551 - val_precision: 0.6695 - val_psnr: 13.4524 - val_ssim_metric: 0.2879
# Epoch 7/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9279 - dice_loss: 0.7160 - loss: 0.1855 - mean_io_u: 0.3857 - precision: 0.7099 - psnr: 13.2633 - ssim_metric: 0.2837 - val_accuracy: 0.9269 - val_dice_loss: 0.8121 - val_loss: 0.2143 - val_mean_io_u: 0.4551 - val_precision: 0.6719 - val_psnr: 12.7957 - val_ssim_metric: 0.2525
# Epoch 8/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9203 - dice_loss: 0.8177 - loss: 0.2148 - mean_io_u: 0.3847 - precision: 0.7517 - psnr: 12.6268 - ssim_metric: 0.2538 - val_accuracy: 0.9281 - val_dice_loss: 0.7892 - val_loss: 0.1981 - val_mean_io_u: 0.4551 - val_precision: 0.6882 - val_psnr: 13.1445 - val_ssim_metric: 0.2634
# Epoch 9/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9233 - dice_loss: 0.7900 - loss: 0.2026 - mean_io_u: 0.3846 - precision: 0.8034 - psnr: 12.9341 - ssim_metric: 0.2643 - val_accuracy: 0.9281 - val_dice_loss: 0.7889 - val_loss: 0.1926 - val_mean_io_u: 0.4551 - val_precision: 0.7083 - val_psnr: 13.2382 - val_ssim_metric: 0.2661
# Epoch 10/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9236 - dice_loss: 0.7801 - loss: 0.2025 - mean_io_u: 0.3851 - precision: 0.7691 - psnr: 12.9120 - ssim_metric: 0.2655 - val_accuracy: 0.9299 - val_dice_loss: 0.7639 - val_loss: 0.1935 - val_mean_io_u: 0.4551 - val_precision: 0.6858 - val_psnr: 13.2810 - val_ssim_metric: 0.2740
# Epoch 11/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9245 - dice_loss: 0.7674 - loss: 0.2013 - mean_io_u: 0.3844 - precision: 0.7862 - psnr: 12.9536 - ssim_metric: 0.2713 - val_accuracy: 0.9311 - val_dice_loss: 0.7507 - val_loss: 0.1985 - val_mean_io_u: 0.4551 - val_precision: 0.6676 - val_psnr: 13.1967 - val_ssim_metric: 0.2809
# Epoch 12/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9259 - dice_loss: 0.7620 - loss: 0.1974 - mean_io_u: 0.3855 - precision: 0.7513 - psnr: 13.0373 - ssim_metric: 0.2715 - val_accuracy: 0.9292 - val_dice_loss: 0.7693 - val_loss: 0.1901 - val_mean_io_u: 0.4551 - val_precision: 0.7089 - val_psnr: 13.3279 - val_ssim_metric: 0.2764
# Epoch 13/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9253 - dice_loss: 0.7526 - loss: 0.1996 - mean_io_u: 0.3843 - precision: 0.7704 - psnr: 12.9878 - ssim_metric: 0.2760 - val_accuracy: 0.9305 - val_dice_loss: 0.7519 - val_loss: 0.1898 - val_mean_io_u: 0.4551 - val_precision: 0.6924 - val_psnr: 13.3722 - val_ssim_metric: 0.2848
# Epoch 14/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9271 - dice_loss: 0.7538 - loss: 0.1969 - mean_io_u: 0.3859 - precision: 0.7545 - psnr: 13.1152 - ssim_metric: 0.2782 - val_accuracy: 0.9304 - val_dice_loss: 0.7504 - val_loss: 0.1886 - val_mean_io_u: 0.4551 - val_precision: 0.6939 - val_psnr: 13.3898 - val_ssim_metric: 0.2799
# Epoch 15/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9261 - dice_loss: 0.7441 - loss: 0.1985 - mean_io_u: 0.3847 - precision: 0.7576 - psnr: 13.0083 - ssim_metric: 0.2768 - val_accuracy: 0.9297 - val_dice_loss: 0.7617 - val_loss: 0.1911 - val_mean_io_u: 0.4551 - val_precision: 0.7078 - val_psnr: 13.3399 - val_ssim_metric: 0.2878
# Epoch 16/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9270 - dice_loss: 0.7369 - loss: 0.1954 - mean_io_u: 0.3849 - precision: 0.7595 - psnr: 13.1072 - ssim_metric: 0.2795 - val_accuracy: 0.9315 - val_dice_loss: 0.7360 - val_loss: 0.1914 - val_mean_io_u: 0.4551 - val_precision: 0.6658 - val_psnr: 13.3499 - val_ssim_metric: 0.2806
# Epoch 17/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9270 - dice_loss: 0.7435 - loss: 0.1981 - mean_io_u: 0.3856 - precision: 0.7371 - psnr: 13.0510 - ssim_metric: 0.2798 - val_accuracy: 0.9268 - val_dice_loss: 0.8306 - val_loss: 0.2265 - val_mean_io_u: 0.4551 - val_precision: 0.7511 - val_psnr: 12.8994 - val_ssim_metric: 0.3588
# Epoch 18/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9277 - dice_loss: 0.7434 - loss: 0.1976 - mean_io_u: 0.3863 - precision: 0.7275 - psnr: 13.1148 - ssim_metric: 0.2834 - val_accuracy: 0.9315 - val_dice_loss: 0.7226 - val_loss: 0.1946 - val_mean_io_u: 0.4551 - val_precision: 0.6335 - val_psnr: 13.2641 - val_ssim_metric: 0.2893
# Epoch 19/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9286 - dice_loss: 0.7279 - loss: 0.1915 - mean_io_u: 0.3857 - precision: 0.7473 - psnr: 13.2064 - ssim_metric: 0.2846 - val_accuracy: 0.9292 - val_dice_loss: 0.7706 - val_loss: 0.1949 - val_mean_io_u: 0.4551 - val_precision: 0.7229 - val_psnr: 13.2664 - val_ssim_metric: 0.3009
# Epoch 20/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9283 - dice_loss: 0.7254 - loss: 0.1914 - mean_io_u: 0.3858 - precision: 0.7270 - psnr: 13.2027 - ssim_metric: 0.2880 - val_accuracy: 0.9311 - val_dice_loss: 0.7324 - val_loss: 0.1824 - val_mean_io_u: 0.4551 - val_precision: 0.6889 - val_psnr: 13.4848 - val_ssim_metric: 0.2855
# Epoch 21/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9286 - dice_loss: 0.7122 - loss: 0.1878 - mean_io_u: 0.3851 - precision: 0.7517 - psnr: 13.2928 - ssim_metric: 0.2893 - val_accuracy: 0.9320 - val_dice_loss: 0.7088 - val_loss: 0.1838 - val_mean_io_u: 0.4551 - val_precision: 0.6433 - val_psnr: 13.4798 - val_ssim_metric: 0.2859
# Epoch 22/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9285 - dice_loss: 0.7103 - loss: 0.1883 - mean_io_u: 0.3850 - precision: 0.7292 - psnr: 13.2553 - ssim_metric: 0.2929 - val_accuracy: 0.9286 - val_dice_loss: 0.7007 - val_loss: 0.2050 - val_mean_io_u: 0.4551 - val_precision: 0.5666 - val_psnr: 12.9670 - val_ssim_metric: 0.2944
# Epoch 23/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9297 - dice_loss: 0.7022 - loss: 0.1842 - mean_io_u: 0.3858 - precision: 0.7229 - psnr: 13.3642 - ssim_metric: 0.2941 - val_accuracy: 0.9262 - val_dice_loss: 0.6985 - val_loss: 0.2104 - val_mean_io_u: 0.4551 - val_precision: 0.5429 - val_psnr: 12.8100 - val_ssim_metric: 0.2955
# Epoch 24/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9299 - dice_loss: 0.6985 - loss: 0.1831 - mean_io_u: 0.3853 - precision: 0.7253 - psnr: 13.3768 - ssim_metric: 0.2966 - val_accuracy: 0.9313 - val_dice_loss: 0.7264 - val_loss: 0.1801 - val_mean_io_u: 0.4551 - val_precision: 0.6930 - val_psnr: 13.5152 - val_ssim_metric: 0.3030
# Epoch 25/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9300 - dice_loss: 0.6911 - loss: 0.1814 - mean_io_u: 0.3852 - precision: 0.7369 - psnr: 13.3838 - ssim_metric: 0.2968 - val_accuracy: 0.9316 - val_dice_loss: 0.7057 - val_loss: 0.1774 - val_mean_io_u: 0.4551 - val_precision: 0.6659 - val_psnr: 13.5727 - val_ssim_metric: 0.3032
# Epoch 26/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9300 - dice_loss: 0.6882 - loss: 0.1808 - mean_io_u: 0.3848 - precision: 0.7299 - psnr: 13.4213 - ssim_metric: 0.3006 - val_accuracy: 0.9301 - val_dice_loss: 0.7487 - val_loss: 0.1872 - val_mean_io_u: 0.4551 - val_precision: 0.7129 - val_psnr: 13.3704 - val_ssim_metric: 0.3200
# Epoch 27/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9300 - dice_loss: 0.6866 - loss: 0.1814 - mean_io_u: 0.3852 - precision: 0.7220 - psnr: 13.3837 - ssim_metric: 0.3003 - val_accuracy: 0.9316 - val_dice_loss: 0.6958 - val_loss: 0.1753 - val_mean_io_u: 0.4551 - val_precision: 0.6383 - val_psnr: 13.6009 - val_ssim_metric: 0.2951
# Epoch 28/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9305 - dice_loss: 0.6913 - loss: 0.1809 - mean_io_u: 0.3857 - precision: 0.7181 - psnr: 13.4491 - ssim_metric: 0.3027 - val_accuracy: 0.9316 - val_dice_loss: 0.6968 - val_loss: 0.1752 - val_mean_io_u: 0.4551 - val_precision: 0.6397 - val_psnr: 13.5963 - val_ssim_metric: 0.2930
# Epoch 29/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9297 - dice_loss: 0.6831 - loss: 0.1810 - mean_io_u: 0.3852 - precision: 0.7069 - psnr: 13.4600 - ssim_metric: 0.3084 - val_accuracy: 0.9318 - val_dice_loss: 0.7046 - val_loss: 0.1754 - val_mean_io_u: 0.4551 - val_precision: 0.6659 - val_psnr: 13.5986 - val_ssim_metric: 0.2986
# Epoch 30/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9292 - dice_loss: 0.6944 - loss: 0.1834 - mean_io_u: 0.3859 - precision: 0.6842 - psnr: 13.4758 - ssim_metric: 0.3083 - val_accuracy: 0.9251 - val_dice_loss: 0.6833 - val_loss: 0.2100 - val_mean_io_u: 0.4551 - val_precision: 0.5386 - val_psnr: 12.8473 - val_ssim_metric: 0.2945
# Epoch 31/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9302 - dice_loss: 0.6809 - loss: 0.1795 - mean_io_u: 0.3851 - precision: 0.7145 - psnr: 13.5098 - ssim_metric: 0.3074 - val_accuracy: 0.9269 - val_dice_loss: 0.8378 - val_loss: 0.2383 - val_mean_io_u: 0.4551 - val_precision: 0.7988 - val_psnr: 12.8681 - val_ssim_metric: 0.4307
# Epoch 32/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9296 - dice_loss: 0.6913 - loss: 0.1877 - mean_io_u: 0.3856 - precision: 0.6951 - psnr: 13.3590 - ssim_metric: 0.3224 - val_accuracy: 0.9304 - val_dice_loss: 0.6943 - val_loss: 0.1843 - val_mean_io_u: 0.4551 - val_precision: 0.6015 - val_psnr: 13.3786 - val_ssim_metric: 0.2941
# Epoch 33/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9300 - dice_loss: 0.6666 - loss: 0.1801 - mean_io_u: 0.3839 - precision: 0.7251 - psnr: 13.4093 - ssim_metric: 0.3119 - val_accuracy: 0.9275 - val_dice_loss: 0.6790 - val_loss: 0.1936 - val_mean_io_u: 0.4551 - val_precision: 0.5613 - val_psnr: 13.2161 - val_ssim_metric: 0.2961
# Epoch 34/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9306 - dice_loss: 0.6865 - loss: 0.1816 - mean_io_u: 0.3856 - precision: 0.7053 - psnr: 13.4198 - ssim_metric: 0.3128 - val_accuracy: 0.9288 - val_dice_loss: 0.6770 - val_loss: 0.1894 - val_mean_io_u: 0.4551 - val_precision: 0.5754 - val_psnr: 13.3200 - val_ssim_metric: 0.2954
# Epoch 35/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9308 - dice_loss: 0.6751 - loss: 0.1776 - mean_io_u: 0.3854 - precision: 0.7197 - psnr: 13.5193 - ssim_metric: 0.3116 - val_accuracy: 0.9305 - val_dice_loss: 0.6744 - val_loss: 0.1836 - val_mean_io_u: 0.4551 - val_precision: 0.5955 - val_psnr: 13.4370 - val_ssim_metric: 0.2971
# Epoch 36/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9286 - dice_loss: 0.6869 - loss: 0.1890 - mean_io_u: 0.3854 - precision: 0.6766 - psnr: 13.3186 - ssim_metric: 0.3233 - val_accuracy: 0.9249 - val_dice_loss: 0.6731 - val_loss: 0.2029 - val_mean_io_u: 0.4551 - val_precision: 0.5387 - val_psnr: 13.0380 - val_ssim_metric: 0.2949
# Epoch 37/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9307 - dice_loss: 0.6744 - loss: 0.1778 - mean_io_u: 0.3854 - precision: 0.7117 - psnr: 13.4638 - ssim_metric: 0.3111 - val_accuracy: 0.9315 - val_dice_loss: 0.7174 - val_loss: 0.1832 - val_mean_io_u: 0.4551 - val_precision: 0.6919 - val_psnr: 13.5010 - val_ssim_metric: 0.3457
# Epoch 38/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9305 - dice_loss: 0.6675 - loss: 0.1782 - mean_io_u: 0.3850 - precision: 0.7133 - psnr: 13.4682 - ssim_metric: 0.3167 - val_accuracy: 0.9319 - val_dice_loss: 0.6823 - val_loss: 0.1712 - val_mean_io_u: 0.4551 - val_precision: 0.6433 - val_psnr: 13.6668 - val_ssim_metric: 0.3098
# Epoch 39/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9314 - dice_loss: 0.6737 - loss: 0.1779 - mean_io_u: 0.3857 - precision: 0.7153 - psnr: 13.5609 - ssim_metric: 0.3189 - val_accuracy: 0.9319 - val_dice_loss: 0.6842 - val_loss: 0.1725 - val_mean_io_u: 0.4551 - val_precision: 0.6468 - val_psnr: 13.6461 - val_ssim_metric: 0.3071
# Epoch 40/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9298 - dice_loss: 0.6686 - loss: 0.1819 - mean_io_u: 0.3848 - precision: 0.6968 - psnr: 13.4176 - ssim_metric: 0.3251 - val_accuracy: 0.9260 - val_dice_loss: 0.6706 - val_loss: 0.1941 - val_mean_io_u: 0.4551 - val_precision: 0.5483 - val_psnr: 13.1790 - val_ssim_metric: 0.2957
# Epoch 41/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9302 - dice_loss: 0.6750 - loss: 0.1793 - mean_io_u: 0.3859 - precision: 0.6860 - psnr: 13.5051 - ssim_metric: 0.3164 - val_accuracy: 0.9305 - val_dice_loss: 0.7383 - val_loss: 0.1958 - val_mean_io_u: 0.4551 - val_precision: 0.7042 - val_psnr: 13.3376 - val_ssim_metric: 0.3852
# Epoch 42/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9309 - dice_loss: 0.6648 - loss: 0.1767 - mean_io_u: 0.3849 - precision: 0.7150 - psnr: 13.5528 - ssim_metric: 0.3188 - val_accuracy: 0.9285 - val_dice_loss: 0.6657 - val_loss: 0.1860 - val_mean_io_u: 0.4551 - val_precision: 0.5722 - val_psnr: 13.3774 - val_ssim_metric: 0.2983
# Epoch 43/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9306 - dice_loss: 0.6660 - loss: 0.1783 - mean_io_u: 0.3850 - precision: 0.7077 - psnr: 13.4926 - ssim_metric: 0.3218 - val_accuracy: 0.9318 - val_dice_loss: 0.6791 - val_loss: 0.1727 - val_mean_io_u: 0.4551 - val_precision: 0.6358 - val_psnr: 13.6489 - val_ssim_metric: 0.3081
# Epoch 44/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9310 - dice_loss: 0.6647 - loss: 0.1788 - mean_io_u: 0.3851 - precision: 0.7099 - psnr: 13.5152 - ssim_metric: 0.3264 - val_accuracy: 0.9319 - val_dice_loss: 0.6969 - val_loss: 0.1723 - val_mean_io_u: 0.4551 - val_precision: 0.6584 - val_psnr: 13.6343 - val_ssim_metric: 0.3150
# Epoch 45/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9301 - dice_loss: 0.6814 - loss: 0.1807 - mean_io_u: 0.3860 - precision: 0.6838 - psnr: 13.4349 - ssim_metric: 0.3184 - val_accuracy: 0.9317 - val_dice_loss: 0.7081 - val_loss: 0.1767 - val_mean_io_u: 0.4551 - val_precision: 0.6823 - val_psnr: 13.5785 - val_ssim_metric: 0.3470
# Epoch 46/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9305 - dice_loss: 0.6612 - loss: 0.1787 - mean_io_u: 0.3846 - precision: 0.7132 - psnr: 13.4792 - ssim_metric: 0.3275 - val_accuracy: 0.9317 - val_dice_loss: 0.6897 - val_loss: 0.1729 - val_mean_io_u: 0.4551 - val_precision: 0.6487 - val_psnr: 13.6306 - val_ssim_metric: 0.3162
# Epoch 47/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9309 - dice_loss: 0.6645 - loss: 0.1775 - mean_io_u: 0.3855 - precision: 0.7041 - psnr: 13.5405 - ssim_metric: 0.3276 - val_accuracy: 0.9289 - val_dice_loss: 0.6590 - val_loss: 0.1827 - val_mean_io_u: 0.4551 - val_precision: 0.5787 - val_psnr: 13.4441 - val_ssim_metric: 0.3003
# Epoch 48/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9305 - dice_loss: 0.6681 - loss: 0.1790 - mean_io_u: 0.3855 - precision: 0.6955 - psnr: 13.4724 - ssim_metric: 0.3245 - val_accuracy: 0.9315 - val_dice_loss: 0.7106 - val_loss: 0.1800 - val_mean_io_u: 0.4551 - val_precision: 0.6809 - val_psnr: 13.5441 - val_ssim_metric: 0.3489
# Epoch 49/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9316 - dice_loss: 0.6615 - loss: 0.1748 - mean_io_u: 0.3855 - precision: 0.7165 - psnr: 13.5973 - ssim_metric: 0.3211 - val_accuracy: 0.9290 - val_dice_loss: 0.6649 - val_loss: 0.1821 - val_mean_io_u: 0.4551 - val_precision: 0.5774 - val_psnr: 13.4421 - val_ssim_metric: 0.2989
# Epoch 50/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.9308 - dice_loss: 0.6664 - loss: 0.1768 - mean_io_u: 0.3857 - precision: 0.6926 - psnr: 13.5728 - ssim_metric: 0.3228 - val_accuracy: 0.9305 - val_dice_loss: 0.6671 - val_loss: 0.1749 - val_mean_io_u: 0.4551 - val_precision: 0.6095 - val_psnr: 13.5920 - val_ssim_metric: 0.3115

# %%
attention.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', MeanIoU(num_classes=2)])  # Replace 'mean_io_u' with your actual IoU metric

# %%
test_loss, test_accuracy, test_miou = attention.evaluate(images_test, masks_test, verbose=1)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Mean IoU: {test_miou}")
# Out:
# 2024-12-24 15:17:19.135862: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 15:17:22.239382: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 1.79427, expected 0.794404
# 2024-12-24 15:17:22.239463: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 2.55447, expected 1.55461
# 2024-12-24 15:17:22.239478: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 2.37298, expected 1.37312
# 2024-12-24 15:17:22.239489: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 2.71847, expected 1.71861
# 2024-12-24 15:17:22.239502: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 2.55181, expected 1.55195
# 2024-12-24 15:17:22.239517: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 2.46424, expected 1.46438
# 2024-12-24 15:17:22.239529: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 2.83149, expected 1.83163
# 2024-12-24 15:17:22.239538: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 2.82969, expected 1.82983
# 2024-12-24 15:17:22.239549: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 2.273, expected 1.27314
# 2024-12-24 15:17:22.239559: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 2.03418, expected 1.03432
# 2024-12-24 15:17:22.612480: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 15:17:22.612547: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 15:17:22.612561: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 15:17:22.612571: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 15:17:22.612583: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 15:17:22.612607: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-12-24 15:17:22.612657: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.476907557s
# Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 15:17:24.915473: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 15:17:27.958740: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 1.79427, expected 0.794404
# 2024-12-24 15:17:27.958806: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 2.55447, expected 1.55461
# 2024-12-24 15:17:27.958821: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 2.37298, expected 1.37312
# 2024-12-24 15:17:27.958836: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 2.71847, expected 1.71861
# 2024-12-24 15:17:27.958851: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 2.55181, expected 1.55195
# 2024-12-24 15:17:27.958861: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 2.46424, expected 1.46438
# 2024-12-24 15:17:27.958872: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 2.83149, expected 1.83163
# 2024-12-24 15:17:27.958883: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 2.82969, expected 1.82983
# 2024-12-24 15:17:27.958894: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 2.273, expected 1.27314
# 2024-12-24 15:17:27.958904: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 2.03418, expected 1.03432
# 2024-12-24 15:17:28.346848: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 15:17:28.346913: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 15:17:28.346928: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 15:17:28.346938: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 15:17:28.346947: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 15:17:28.346969: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-12-24 15:17:28.347016: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.431675948s
# Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 15:17:36.097638: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,512,512]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 15:17:36.207137: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.109648194s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,512,512]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 15:17:41.759364: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,512,512]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 15:17:41.868820: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.109575115s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,512,512]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9288 - loss: 0.1761 - mean_io_u_1: 0.4625
# 2024-12-24 15:18:02.394168: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 0.925107, expected 0.534345
# 2024-12-24 15:18:02.394232: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 1.48528, expected 1.09452
# 2024-12-24 15:18:02.394242: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 1.1634, expected 0.772635
# 2024-12-24 15:18:02.394250: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 1.71021, expected 1.31945
# 2024-12-24 15:18:02.394258: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 1.49143, expected 1.10067
# 2024-12-24 15:18:02.394265: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 1.15516, expected 0.764399
# 2024-12-24 15:18:02.394273: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 1.81655, expected 1.42579
# 2024-12-24 15:18:02.394281: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 1.83284, expected 1.44208
# 2024-12-24 15:18:02.394289: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 1.18872, expected 0.797957
# 2024-12-24 15:18:02.394297: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 1.28963, expected 0.898872
# 2024-12-24 15:18:02.442159: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=3,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 15:18:02.442222: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 15:18:02.442231: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 15:18:02.442238: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 15:18:02.442245: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 15:18:02.442262: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-12-24 15:18:03.134308: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 0.925107, expected 0.534345
# 2024-12-24 15:18:03.134380: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 1.48528, expected 1.09452
# 2024-12-24 15:18:03.134390: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 1.1634, expected 0.772635
# 2024-12-24 15:18:03.134398: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 1.71021, expected 1.31945
# 2024-12-24 15:18:03.134406: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 1.49143, expected 1.10067
# 2024-12-24 15:18:03.134413: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 1.15516, expected 0.764399
# 2024-12-24 15:18:03.134421: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 1.81655, expected 1.42579
# 2024-12-24 15:18:03.134429: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 1.83284, expected 1.44208
# 2024-12-24 15:18:03.134437: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 1.18872, expected 0.797957
# 2024-12-24 15:18:03.134444: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 1.28963, expected 0.898872
# 2024-12-24 15:18:03.182530: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=3,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 15:18:03.182603: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 15:18:03.182612: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 15:18:03.182619: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 15:18:03.182626: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 15:18:03.182644: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.9291 - loss: 0.1760 - mean_io_u_1: 0.4588
# Test Loss: 0.17570380866527557
# Test Accuracy: 0.9296400547027588
# Mean IoU: 0.4532955586910248

# %%
attention.save("attention_segmentation_model.h5")

# %%
attention.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 512, 512,  │        640 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 512, 512,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 256, 256,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 256, 256,  │    147,712 │ max_pooling2d[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 512, 512,  │     65,600 │ conv2d_2[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 512, 512,  │      2,080 │ conv2d_1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 512, 512,  │      2,080 │ conv2d_transpose… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 512, 512,  │          0 │ conv2d_3[0][0],   │
# │                     │ 32)               │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 512, 512,  │          0 │ add[0][0]         │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 512, 512,  │         33 │ activation[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 512, 512,  │          0 │ conv2d_5[0][0]    │
# │ (Activation)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 512, 512,  │          0 │ conv2d_1[0][0],   │
# │                     │ 64)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 512, 512,  │         65 │ multiply[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 255,138 (996.63 KB)
#  Trainable params: 255,138 (996.63 KB)
#  Non-trainable params: 0 (0.00 B)
