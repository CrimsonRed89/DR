# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf
from pathlib import Path
import cv2
import time
import random
from PIL import Image 

import torch
import torch.nn as nn
import torch.optim as optim

from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, transforms
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf
from pathlib import Path
import cv2
import time
import random
from PIL import Image 

import torch
import torch.nn as nn
import torch.optim as optim

from torch.optim import lr_scheduler
import torchvision
from keras import utils
from torchvision import datasets, transforms
from tensorflow.keras.optimizers import SGD

from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications import InceptionResNetV2

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from sklearn.metrics import matthews_corrcoef, cohen_kappa_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

print("All Libraries Imported Successfully")
# Out:
# All Libraries Imported Successfully

# %% [markdown]
# # Data Preprocessing & EDA

# %%
IMAGE_SIZE = (128, 128)  # Resize all images to 128x128
NUM_CLASSES = 4  # Number of classes: A, D, N, G
CLASS_MAPPING = {'A': 0, 'D': 1, 'N': 2, 'G': 3}

# %%
train_folder = "/kaggle/input/fives-a-fundus-image/FIVES A Fundus Image Dataset for AI-based Vessel Segmentation/train/Original"
test_folder = "/kaggle/input/fives-a-fundus-image/FIVES A Fundus Image Dataset for AI-based Vessel Segmentation/test/Original"

# %%
def load_images_from_folder(folder):
    images = []
    labels = []

    # List all files in the folder
    for file_name in os.listdir(folder):
        try:
            # Extract label from file name (e.g., "123_A.png")
            if "_" in file_name and file_name.endswith(".png"):
                _, disease = file_name.split("_")
                disease = disease.split(".")[0]  # Remove the ".png" extension

                if disease in CLASS_MAPPING:
                    # Load and preprocess image
                    file_path = os.path.join(folder, file_name)
                    img = load_img(file_path, target_size=IMAGE_SIZE)
                    img_array = img_to_array(img) / 255.0  # Normalize to [0, 1]
                    images.append(img_array)

                    # Map disease to class label
                    labels.append(CLASS_MAPPING[disease])
                else:
                    print(f"Unknown label found in file: {file_name}")
        except Exception as e:
            print(f"Error processing file {file_name}: {e}")

    # Convert to numpy arrays
    return np.array(images, dtype='float32'), np.array(labels, dtype='int')

# %%
train_images, train_labels = load_images_from_folder(train_folder)
test_images, test_labels = load_images_from_folder(test_folder)

# %%
train_labels = to_categorical(train_labels, NUM_CLASSES)
test_labels = to_categorical(test_labels, NUM_CLASSES)

# %%
print(f"Train images shape: {train_images.shape}, Train labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}, Test labels shape: {test_labels.shape}")
# Out:
# Train images shape: (600, 128, 128, 3), Train labels shape: (600, 4)
# Test images shape: (200, 128, 128, 3), Test labels shape: (200, 4)

# %%
from collections import Counter

# Decode one-hot encoded labels to class indices
decoded_train_labels = np.argmax(train_labels, axis=1)

decoded_test_labels = np.argmax(test_labels, axis=1)

# Count classes in train, validation, and test labels
train_class_counts = Counter(decoded_train_labels)

test_class_counts = Counter(decoded_test_labels)

# Map class indices back to labels
reverse_class_mapping = {v: k for k, v in CLASS_MAPPING.items()}

print("Train Class Distribution:")
for class_idx, count in train_class_counts.items():
    print(f"{reverse_class_mapping[class_idx]}: {count} images")

print("\nTest Class Distribution:")
for class_idx, count in test_class_counts.items():
    print(f"{reverse_class_mapping[class_idx]}: {count} images")
# Out:
# Train Class Distribution:
# G: 150 images
# D: 150 images
# N: 150 images
# A: 150 images
#
# Test Class Distribution:
# D: 50 images
# G: 50 images
# N: 50 images
# A: 50 images

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create an ImageDataGenerator for augmentation
train_datagen = ImageDataGenerator(
    rotation_range=20,        # Rotate images up to 20 degrees
    width_shift_range=0.2,    # Shift images horizontally up to 20% of the width
    height_shift_range=0.2,   # Shift images vertically up to 20% of the height
    shear_range=0.2,          # Shear transformations
    zoom_range=0.2,           # Zoom in or out by 20%
    horizontal_flip=True,     # Randomly flip images horizontally
    fill_mode='nearest'       # Fill in missing pixels with the nearest value
)

# %%
test_datagen = ImageDataGenerator()

# %%
train_datagen.fit(train_images)

test_datagen.fit(test_images)

# %%
train_generator = train_datagen.flow(train_images, train_labels, batch_size=32)

test_generator = test_datagen.flow(test_images, test_labels, batch_size=32)

# %%
import matplotlib.pyplot as plt

# Generate augmented images
augmented_images, augmented_labels = next(train_generator)

# Plot a few examples
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[i])
    plt.axis('off')
plt.show()

# %%
# Model Architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Define the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(NUM_CLASSES, activation='softmax')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_images) // 32,  # Number of batches per epoch
    epochs=50
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 321ms/step - accuracy: 0.2374 - loss: 1.6547
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - accuracy: 0.2812 - loss: 1.3914
# Epoch 3/50
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.3276 - loss: 1.3743
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step - accuracy: 0.2917 - loss: 1.3740
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.3661 - loss: 1.3302
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 293us/step - accuracy: 0.4375 - loss: 1.2704
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.3855 - loss: 1.2320
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 287us/step - accuracy: 0.4375 - loss: 1.1323
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.4038 - loss: 1.1934
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - accuracy: 0.5625 - loss: 1.0079
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.4124 - loss: 1.1580
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.4688 - loss: 1.2570
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.4560 - loss: 1.1428
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - accuracy: 0.6250 - loss: 0.9399
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.4362 - loss: 1.1579
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - accuracy: 0.4688 - loss: 1.1349
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.5216 - loss: 1.1088
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.5938 - loss: 0.9949
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.4650 - loss: 1.0864
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.4375 - loss: 1.1205
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5581 - loss: 1.0502
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 280us/step - accuracy: 0.3750 - loss: 1.1170
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.5988 - loss: 0.9647
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 285us/step - accuracy: 0.6250 - loss: 1.0418
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5315 - loss: 1.0178
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step - accuracy: 0.5938 - loss: 1.0193
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5480 - loss: 1.0202
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 285us/step - accuracy: 0.6875 - loss: 0.8592
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.6216 - loss: 0.9092
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - accuracy: 0.5625 - loss: 0.9584
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.6260 - loss: 0.8870
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step - accuracy: 0.6875 - loss: 0.9340
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5998 - loss: 0.9192
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step - accuracy: 0.5938 - loss: 0.9173
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.5978 - loss: 0.9490
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - accuracy: 0.6562 - loss: 0.8798
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.6616 - loss: 0.8217
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.4062 - loss: 1.2495
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6303 - loss: 0.9100
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - accuracy: 0.6250 - loss: 0.7644
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.6653 - loss: 0.8283
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.6250 - loss: 0.9213
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.6405 - loss: 0.8554
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 287us/step - accuracy: 0.6250 - loss: 1.0172
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.6531 - loss: 0.8433
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - accuracy: 0.5312 - loss: 1.0168
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.6413 - loss: 0.8663
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.6875 - loss: 0.7003
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.6837 - loss: 0.8181
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 293us/step - accuracy: 0.5312 - loss: 0.9120

# %%
test_loss, test_accuracy = model.evaluate(test_images, test_labels, batch_size=32)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.5261 - loss: 1.2482
# Test Loss: 1.1931159496307373, Test Accuracy: 0.5350000262260437

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Train Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # VGG16

# %%
vgg16 = VGG16(input_shape=(128,128,3), weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
print(f"Train images shape: {train_images.shape}, Train labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}, Test labels shape: {test_labels.shape}")
# Out:
# Train images shape: (600, 128, 128, 3), Train labels shape: (600, 4)
# Test images shape: (200, 128, 128, 3), Test labels shape: (200, 4)

# %%
for layer in vgg16.layers:
    layer.trainable = False

# %%
flat = Flatten()(vgg16.output)

dense1 = Dense(64, kernel_initializer='he_uniform')(flat)
act1 = Activation('relu')(dense1)

dense2 = Dense(128, kernel_initializer='he_uniform')(act1)
act2 = Activation('relu')(dense2)

dense3 = Dense(256, kernel_initializer='he_uniform')(act2)
act3 = Activation('relu')(dense3)

dense4 = Dense(128, kernel_initializer='he_uniform')(act3)
act4 = Activation('relu')(dense4)

dense5 = Dense(64, kernel_initializer='he_uniform')(act4)
act5 = Activation('relu')(dense5)

output = Dense(4, activation='softmax')(act5)

# %%
final_vgg16 = Model(inputs=vgg16.input,outputs=output)

# %%
final_vgg16.compile(optimizer=Adam(learning_rate=0.001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
history = final_vgg16.fit(
train_generator,# Validation data and labels
    batch_size=32,
    epochs=30
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 263ms/step - accuracy: 0.2896 - loss: 1.5268
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.4879 - loss: 1.1702
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5109 - loss: 1.0719
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5846 - loss: 0.9941
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5719 - loss: 0.9422
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6247 - loss: 0.8637
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.5514 - loss: 1.0033
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6473 - loss: 0.8503
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5919 - loss: 0.8587
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6096 - loss: 0.8877
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.6416 - loss: 0.8878
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6136 - loss: 0.8779
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5882 - loss: 0.9000
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6250 - loss: 0.8343
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.6407 - loss: 0.7870
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.6331 - loss: 0.8355
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6268 - loss: 0.8102
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6311 - loss: 0.8333
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6108 - loss: 0.8460
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.6663 - loss: 0.7902
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6605 - loss: 0.8204
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6278 - loss: 0.8967
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6910 - loss: 0.7352
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6353 - loss: 0.8758
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.5694 - loss: 0.8984
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6250 - loss: 0.7850
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6530 - loss: 0.7703
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6882 - loss: 0.7240
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6731 - loss: 0.7367
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.5964 - loss: 0.8859

# %%
test_loss, test_accuracy = model.evaluate(test_images, test_labels, batch_size=32)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5347 - loss: 1.1183
# Test Loss: 1.0682834386825562, Test Accuracy: 0.5400000214576721

# %%
final_2 = Model(inputs=vgg16.input,outputs=output)

# %%
final_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print(f"Train images shape: {train_images.shape}, Train labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}, Test labels shape: {test_labels.shape}")
# Out:
# Train images shape: (600, 128, 128, 3), Train labels shape: (600, 4)
# Test images shape: (200, 128, 128, 3), Test labels shape: (200, 4)

# %%
history = final_2.fit(
    train_images,
    train_labels,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9614 - loss: 0.1254
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8960 - loss: 0.2573
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9050 - loss: 0.2404
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9222 - loss: 0.2084
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9653 - loss: 0.1103
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9695 - loss: 0.1195
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9735 - loss: 0.0753
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8724 - loss: 0.3236
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9313 - loss: 0.1643
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9599 - loss: 0.1248
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9343 - loss: 0.1657
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9560 - loss: 0.1211
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9755 - loss: 0.0718
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9753 - loss: 0.0774
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9571 - loss: 0.1229
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9809 - loss: 0.0535
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9753 - loss: 0.0694
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9533 - loss: 0.1263
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8936 - loss: 0.2569
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9146 - loss: 0.3403
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9552 - loss: 0.1226
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9487 - loss: 0.1111
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8558 - loss: 0.4480
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9353 - loss: 0.1813
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9746 - loss: 0.0511
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9729 - loss: 0.0689
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9617 - loss: 0.0937
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9285 - loss: 0.1507
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9582 - loss: 0.1108
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9457 - loss: 0.1572

# %%
import numpy as np

# Predict the test data
y_pred = final_2.predict(test_images)

# Convert predictions and true labels to their respective classes
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicted class
y_true_classes = np.argmax(test_labels, axis=1)  # True class
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step

# %%
from sklearn.metrics import classification_report

# Generate the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 1       0.79      0.68      0.73        50
#      Class 2       0.67      0.80      0.73        50
#      Class 3       1.00      0.34      0.51        50
#      Class 4       0.55      0.88      0.68        50
#
#     accuracy                           0.68       200
#    macro avg       0.75      0.68      0.66       200
# weighted avg       0.75      0.68      0.66       200

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 1', 'Class 2', 'Class 3', 'Class 4'], yticklabels=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
final_2.save("VGG16_FIVE.h5")

# %%
import matplotlib.pyplot as plt

# Invert CLASS_MAPPING to get label-to-class mapping
CLASS_MAPPING = {'A': 0, 'D': 1, 'N': 2, 'G': 3}
LABEL_MAPPING = {v: k for k, v in CLASS_MAPPING.items()}

# Select 5 random images from the test dataset
indices = np.random.choice(len(test_images), 5, replace=False)

# Plot the images with actual and predicted labels
plt.figure(figsize=(15, 10))
for i, idx in enumerate(indices):
    image = test_images[idx]
    actual_label = LABEL_MAPPING[np.argmax(test_labels[idx])]
    predicted_label = LABEL_MAPPING[np.argmax(y_pred[idx])]

    plt.subplot(1, 5, i + 1)
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"Actual: {actual_label}\nPredicted: {predicted_label}")

plt.tight_layout()
plt.show()

# %% [markdown]
# # VGG19

# %%
vgg19 = VGG19(input_shape=(128,128,3), weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
for layer in vgg19.layers:
    layer.trainable = False

# %%
x = Flatten()(vgg19.output)
dense1 = Dense(64, kernel_initializer='he_uniform')(x)
act1 = Activation('relu')(dense1)

dense2 = Dense(128, kernel_initializer='he_uniform')(act1)
act2 = Activation('relu')(dense2)

dense3 = Dense(256, kernel_initializer='he_uniform')(act2)
act3 = Activation('relu')(dense3)

dense4 = Dense(128, kernel_initializer='he_uniform')(act3)
act4 = Activation('relu')(dense4)

dense5 = Dense(64, kernel_initializer='he_uniform')(act4)
act5 = Activation('relu')(dense5)

predictions = Dense(4, activation='softmax')(act5)

# %%
final_vgg19 = Model(inputs=vgg19.input,outputs=predictions)

# %%
final_vgg19.compile(optimizer=Adam(learning_rate=0.001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
history = final_vgg19.fit(
train_generator,# Validation data and labels
    batch_size=32,
    epochs=30
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.2513 - loss: 1.5597
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.4421 - loss: 1.2674
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.4944 - loss: 1.1388
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.5222 - loss: 1.0424
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.5393 - loss: 1.0266
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.5902 - loss: 0.9445
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5580 - loss: 0.9771
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.5873 - loss: 0.9416
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5471 - loss: 1.0029
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.5568 - loss: 0.9437
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6167 - loss: 0.8903
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.6152 - loss: 0.8873
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5604 - loss: 0.9364
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.5965 - loss: 0.9032
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.5677 - loss: 0.9313
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5741 - loss: 0.8825
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6383 - loss: 0.8142
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.5909 - loss: 0.9609
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5899 - loss: 0.9250
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.6443 - loss: 0.8465
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5784 - loss: 0.8688
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6284 - loss: 0.8585
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.6329 - loss: 0.8651
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.6071 - loss: 0.8245
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6380 - loss: 0.7949
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6447 - loss: 0.8465
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.6122 - loss: 0.8829
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.6248 - loss: 0.8658
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6258 - loss: 0.7900
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6510 - loss: 0.7936

# %%
final_vgg19_2 = Model(inputs=vgg16.input,outputs=output)

# %%
final_vgg19_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = final_vgg19_2.fit(
    train_images,
    train_labels,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.9134 - loss: 0.3369
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9834 - loss: 0.0495
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9686 - loss: 0.0697
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9852 - loss: 0.0358
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9860 - loss: 0.0359
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9682 - loss: 0.0973
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9516 - loss: 0.1503
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9566 - loss: 0.1170
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9971 - loss: 0.0327
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9789 - loss: 0.0549
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9878 - loss: 0.0406
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9966 - loss: 0.0146
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9967 - loss: 0.0088
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9997 - loss: 0.0033
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9976 - loss: 0.0122
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9507 - loss: 0.1739
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8692 - loss: 0.3762
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9815 - loss: 0.0890
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9869 - loss: 0.0488
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9903 - loss: 0.0247
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9822 - loss: 0.0675
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9265 - loss: 0.1912
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9680 - loss: 0.0993
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9377 - loss: 0.2268
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9869 - loss: 0.0320
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9831 - loss: 0.0621
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9668 - loss: 0.1012
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9725 - loss: 0.0602
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9976 - loss: 0.0148

# %%
test_loss, test_accuracy = final_vgg19_2.evaluate(test_images, test_labels, batch_size=32)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.6155 - loss: 2.6182
# Test Loss: 2.5270919799804688, Test Accuracy: 0.625

# %%
import numpy as np

# Predict the test data
y_pred = final_vgg19_2.predict(test_images)

# Convert predictions and true labels to their respective classes
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicted class
y_true_classes = np.argmax(test_labels, axis=1)  # True class
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step

# %%
from sklearn.metrics import classification_report

# Generate the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 1       0.78      0.70      0.74        50
#      Class 2       0.57      0.80      0.67        50
#      Class 3       1.00      0.16      0.28        50
#      Class 4       0.55      0.84      0.66        50
#
#     accuracy                           0.62       200
#    macro avg       0.72      0.62      0.59       200
# weighted avg       0.72      0.62      0.59       200

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 1', 'Class 2', 'Class 3', 'Class 4'], yticklabels=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt

# Invert CLASS_MAPPING to get label-to-class mapping
CLASS_MAPPING = {'A': 0, 'D': 1, 'N': 2, 'G': 3}
LABEL_MAPPING = {v: k for k, v in CLASS_MAPPING.items()}

# Select 5 random images from the test dataset
indices = np.random.choice(len(test_images), 5, replace=False)

# Plot the images with actual and predicted labels
plt.figure(figsize=(15, 10))
for i, idx in enumerate(indices):
    image = test_images[idx]
    actual_label = LABEL_MAPPING[np.argmax(test_labels[idx])]
    predicted_label = LABEL_MAPPING[np.argmax(y_pred[idx])]

    plt.subplot(1, 5, i + 1)
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"Actual: {actual_label}\nPredicted: {predicted_label}")

plt.tight_layout()
plt.show()

# %%
final_vgg19_2.save("VGG19.h5")

# %% [markdown]
# # ResNet 50

# %%
resnet50 = ResNet50(input_shape=(128,128,3), weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
x = Flatten()(resnet50.output)

dense1 = Dense(64, kernel_initializer='he_uniform')(x)
bn1 = BatchNormalization()(dense1)
act1 = Activation('relu')(bn1)

dense2 = Dense(128, kernel_initializer='he_uniform')(act1)
act2 = Activation('relu')(dense2)

dense3 = Dense(256, kernel_initializer='he_uniform')(act2)
act3 = Activation('relu')(dense3)

dense4 = Dense(128, kernel_initializer='he_uniform')(act3)
act4 = Activation('relu')(dense4)

dense5 = Dense(64, kernel_initializer='he_uniform')(act4)
act5 = Activation('relu')(dense5)

predictions = Dense(4, activation='softmax')(act5)

# %%
final_resnet50 = Model(inputs=resnet50.input, outputs=predictions)

# %%
final_resnet50.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = final_resnet50.fit(
    train_images,
    train_labels,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.5214 - loss: 1.1808
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8126 - loss: 0.5216
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8610 - loss: 0.3645
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8849 - loss: 0.3089
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9266 - loss: 0.2015
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9406 - loss: 0.1637
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9525 - loss: 0.1593
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9589 - loss: 0.1277
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9353 - loss: 0.1624
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9317 - loss: 0.2060
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9451 - loss: 0.1713
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9807 - loss: 0.0728
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9495 - loss: 0.1190
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9827 - loss: 0.0838
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9783 - loss: 0.0662
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9808 - loss: 0.0662
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9716 - loss: 0.0700
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9925 - loss: 0.0420
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9714 - loss: 0.0867
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9832 - loss: 0.0472
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9834 - loss: 0.0514
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9463 - loss: 0.2093
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9619 - loss: 0.0962
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9802 - loss: 0.0552
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9715 - loss: 0.0861
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9943 - loss: 0.0247
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9941 - loss: 0.0195
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9934 - loss: 0.0153
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9937 - loss: 0.0120
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9966 - loss: 0.0098

# %%
history = final_resnet50.fit(
    train_generator,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8733 - loss: 0.3567
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.8714 - loss: 0.3449
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8595 - loss: 0.4060
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9266 - loss: 0.2730
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8851 - loss: 0.2993
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8819 - loss: 0.2943
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.8817 - loss: 0.3437
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8826 - loss: 0.3021
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8996 - loss: 0.2705
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.9064 - loss: 0.2530
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8881 - loss: 0.2901
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9057 - loss: 0.3247
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8603 - loss: 0.3818
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.9093 - loss: 0.2773
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.9082 - loss: 0.2565
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9130 - loss: 0.2249
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9083 - loss: 0.2361
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9055 - loss: 0.2395
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.9218 - loss: 0.2235
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9322 - loss: 0.2562
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.9046 - loss: 0.2612
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8998 - loss: 0.2475
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.9208 - loss: 0.2066
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9085 - loss: 0.2238
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.9427 - loss: 0.2056
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.9085 - loss: 0.2627
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9261 - loss: 0.2112
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.9259 - loss: 0.2142
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.9468 - loss: 0.1610
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9434 - loss: 0.2048

# %%
test_loss, test_accuracy = final_resnet50.evaluate(test_images, test_labels, batch_size=32)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6526 - loss: 1.3534
# Test Loss: 1.259161114692688, Test Accuracy: 0.6700000166893005

# %%
import numpy as np

# Predict the test data
y_pred = final_resnet50.predict(test_images)

# Convert predictions and true labels to their respective classes
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicted class
y_true_classes = np.argmax(test_labels, axis=1)  # True class
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
from sklearn.metrics import classification_report

# Generate the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 1       0.85      0.90      0.87        50
#      Class 2       0.52      0.76      0.62        50
#      Class 3       0.75      0.12      0.21        50
#      Class 4       0.68      0.90      0.78        50
#
#     accuracy                           0.67       200
#    macro avg       0.70      0.67      0.62       200
# weighted avg       0.70      0.67      0.62       200

# %%
final_resnet50.save("resnet50.h5")

# %% [markdown]
# # Mobile Net

# %%
mobilenet = MobileNetV2(input_shape=(128,128,3), weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
x = Flatten()(mobilenet.output)

dense1 = Dense(64, kernel_initializer='he_uniform')(x)
act1 = Activation('relu')(dense1)

dense2 = Dense(128, kernel_initializer='he_uniform')(act1)
act2 = Activation('relu')(dense2)

dense3 = Dense(256, kernel_initializer='he_uniform')(act2)
act3 = Activation('relu')(dense3)

dense4 = Dense(128, kernel_initializer='he_uniform')(act3)
act4 = Activation('relu')(dense4)

dense5 = Dense(64, kernel_initializer='he_uniform')(act4)
act5 = Activation('relu')(dense5)

predictions = Dense(4, activation='softmax')(act5)

# %%
final_mobilenet = Model(inputs=mobilenet.input, outputs=predictions)

# %%
final_mobilenet.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = final_mobilenet.fit(
    train_generator,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 37s 778ms/step - accuracy: 0.6600 - loss: 1.5094
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.7542 - loss: 0.7986
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.7986 - loss: 0.6030
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.8391 - loss: 0.5537
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.8552 - loss: 0.4434
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.8725 - loss: 0.3831
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.8809 - loss: 0.3804
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.8797 - loss: 0.3273
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.8792 - loss: 0.3465
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.8968 - loss: 0.3389
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9147 - loss: 0.2784
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8786 - loss: 0.3607
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9171 - loss: 0.2786
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9045 - loss: 0.2931
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.8865 - loss: 0.3116
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.8918 - loss: 0.3264
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.9028 - loss: 0.2847
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8912 - loss: 0.2883
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.9121 - loss: 0.2740
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9134 - loss: 0.3516
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8864 - loss: 0.3576
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.8869 - loss: 0.3662
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9007 - loss: 0.3340
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.8877 - loss: 0.3377
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9225 - loss: 0.2291
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9418 - loss: 0.2153
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9326 - loss: 0.2321
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.9284 - loss: 0.2343
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9301 - loss: 0.2349
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9182 - loss: 0.2450

# %%
test_loss, test_accuracy = final_mobilenet.evaluate(test_images, test_labels, batch_size=32)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - accuracy: 0.3199 - loss: 2.1504
# Test Loss: 2.1208319664001465, Test Accuracy: 0.33500000834465027

# %%
final_mobilenet.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = final_mobilenet.fit(
    train_images,
    train_labels,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 51s 827ms/step - accuracy: 0.8676 - loss: 0.4591
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8985 - loss: 0.3497
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9413 - loss: 0.2304
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9410 - loss: 0.2664
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8957 - loss: 0.3671
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9580 - loss: 0.1423
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9426 - loss: 0.2273
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9423 - loss: 0.1849
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9280 - loss: 0.5773
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8862 - loss: 0.5733
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9141 - loss: 0.3771
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9163 - loss: 0.3102
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9584 - loss: 0.1335
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9487 - loss: 0.1509
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9163 - loss: 0.3027
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8880 - loss: 0.3427
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9492 - loss: 0.1317
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9263 - loss: 0.2439
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9632 - loss: 0.1022
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9636 - loss: 0.1254
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9687 - loss: 0.1107
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9848 - loss: 0.0736
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9664 - loss: 0.1327
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9402 - loss: 0.3760
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9016 - loss: 0.4801
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9655 - loss: 0.1127
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9690 - loss: 0.0793
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9931 - loss: 0.0306
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9984 - loss: 0.0065
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9947 - loss: 0.0168

# %%
test_loss, test_accuracy = final_mobilenet.evaluate(test_images, test_labels, batch_size=32)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4035 - loss: 7.1880
# Test Loss: 7.274559497833252, Test Accuracy: 0.42500001192092896

# %%
import numpy as np

# Predict the test data
y_pred = final_mobilenet.predict(test_images)

# Convert predictions and true labels to their respective classes
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicted class
y_true_classes = np.argmax(test_labels, axis=1)  # True class
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 388ms/step

# %%
from sklearn.metrics import classification_report

# Generate the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 1       0.32      0.96      0.48        50
#      Class 2       1.00      0.06      0.11        50
#      Class 3       0.76      0.58      0.66        50
#      Class 4       0.62      0.10      0.17        50
#
#     accuracy                           0.42       200
#    macro avg       0.68      0.43      0.36       200
# weighted avg       0.68      0.42      0.36       200

# %%
final_mobilenet.save("mobilenet.h5")

# %% [markdown]
# # Inception

# %%
inception = InceptionResNetV2(input_shape=(128,128,3), weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step

# %%
x = inception.output
flat = Flatten()(x)

dense1 = Dense(64, kernel_initializer='he_uniform')(flat)
act1 = Activation('relu')(dense1)

dense2 = Dense(128, kernel_initializer='he_uniform')(act1)
act2 = Activation('relu')(dense2)

dense3 = Dense(256, kernel_initializer='he_uniform')(act2)
act3 = Activation('relu')(dense3)

dense4 = Dense(128, kernel_initializer='he_uniform')(act3)
act4 = Activation('relu')(dense4)

dense5 = Dense(64, kernel_initializer='he_uniform')(act4)
act5 = Activation('relu')(dense5)

predictions = Dense(4, activation='softmax')(act5)

# %%
final_inception = Model(inputs=inception.input,outputs=predictions)

# %%
final_inception.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = final_inception.fit(
    train_generator,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 215s 4s/step - accuracy: 0.3654 - loss: 1.4426
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.6172 - loss: 0.9683
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.6104 - loss: 0.9808
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.6822 - loss: 0.8107
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.6949 - loss: 0.7980
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.7496 - loss: 0.6475
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.7829 - loss: 0.6276
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.7620 - loss: 0.6642
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8021 - loss: 0.5745
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8109 - loss: 0.5792
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.7629 - loss: 0.6462
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.7720 - loss: 0.6286
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8094 - loss: 0.5467
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8045 - loss: 0.5452
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8370 - loss: 0.4431
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8234 - loss: 0.5425
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7639 - loss: 0.6346
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.8088 - loss: 0.5244
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8355 - loss: 0.4974
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8209 - loss: 0.5097
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8428 - loss: 0.4693
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8147 - loss: 0.4808
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8455 - loss: 0.4597
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7896 - loss: 0.5772
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.8517 - loss: 0.4161
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8462 - loss: 0.4092
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8164 - loss: 0.4787
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.8334 - loss: 0.4328
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.8480 - loss: 0.4865
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8264 - loss: 0.4729

# %%
test_loss, test_accuracy = final_inception.evaluate(test_images, test_labels, batch_size=32)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7477 - loss: 1.4184
# Test Loss: 1.2431453466415405, Test Accuracy: 0.7599999904632568

# %%
history = final_inception.fit(
    train_images,
    train_labels,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 164s 3s/step - accuracy: 0.8397 - loss: 0.4950
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8918 - loss: 0.3372
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9427 - loss: 0.1665
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9298 - loss: 0.1781
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8974 - loss: 0.3283
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8996 - loss: 0.2821
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9358 - loss: 0.1779
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9380 - loss: 0.1476
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9629 - loss: 0.1214
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9800 - loss: 0.0593
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9700 - loss: 0.1671
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9713 - loss: 0.1040
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9728 - loss: 0.0993
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9807 - loss: 0.0604
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9468 - loss: 0.1867
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8963 - loss: 0.2921
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9412 - loss: 0.1840
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9517 - loss: 0.1532
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9817 - loss: 0.0994
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9752 - loss: 0.0927
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9240 - loss: 0.2092
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8894 - loss: 0.2920
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9091 - loss: 0.2124
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9564 - loss: 0.1263
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9436 - loss: 0.1549
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9716 - loss: 0.1210
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9702 - loss: 0.0817
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9581 - loss: 0.1113
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9768 - loss: 0.0747
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9756 - loss: 0.0724

# %%
final_inception.save("inception.h5")

# %%
import numpy as np

# Predict the test data
y_pred = final_inception.predict(test_images)

# Convert predictions and true labels to their respective classes
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicted class
y_true_classes = np.argmax(test_labels, axis=1)  # True class
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step

# %%
from sklearn.metrics import classification_report

# Generate the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 1       0.89      0.84      0.87        50
#      Class 2       1.00      0.64      0.78        50
#      Class 3       0.78      0.62      0.69        50
#      Class 4       0.58      0.94      0.72        50
#
#     accuracy                           0.76       200
#    macro avg       0.81      0.76      0.76       200
# weighted avg       0.81      0.76      0.76       200

# %%
import matplotlib.pyplot as plt

# Invert CLASS_MAPPING to get label-to-class mapping
CLASS_MAPPING = {'A': 0, 'D': 1, 'N': 2, 'G': 3}
LABEL_MAPPING = {v: k for k, v in CLASS_MAPPING.items()}

# Select 5 random images from the test dataset
indices = np.random.choice(len(test_images), 5, replace=False)

# Plot the images with actual and predicted labels
plt.figure(figsize=(15, 10))
for i, idx in enumerate(indices):
    image = test_images[idx]
    actual_label = LABEL_MAPPING[np.argmax(test_labels[idx])]
    predicted_label = LABEL_MAPPING[np.argmax(y_pred[idx])]

    plt.subplot(1, 5, i + 1)
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"Actual: {actual_label}\nPredicted: {predicted_label}")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 1', 'Class 2', 'Class 3', 'Class 4'], yticklabels=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Efficient Net

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers

# %%
efficientnet = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(128,128, 3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
flat = layers.Flatten()(efficientnet.output)
dense1 = layers.Dense(2048, activation="relu")(flat)
dropout1 = layers.Dropout(0.4)(dense1)
dense2 = layers.Dense(2048, activation="relu")(dropout1)
dropout2 = layers.Dropout(0.4)(dense2)
output = layers.Dense(4, activation="softmax")(dropout2)

# %%
final_efficient = tf.keras.models.Model(inputs=[efficientnet.input], outputs=[output])

# %%
final_efficient.compile(optimizer=SGD(learning_rate=3e-4, momentum=0.9),
              loss="categorical_crossentropy",
              metrics=['accuracy'])

# %%
history = final_efficient.fit(
    train_generator,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7250 - loss: 0.6359
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7247 - loss: 0.6858
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7848 - loss: 0.5901
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.7094 - loss: 0.7098
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.7480 - loss: 0.6136
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.7339 - loss: 0.6841
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.7505 - loss: 0.6363
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7595 - loss: 0.6136
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.7401 - loss: 0.6354
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7594 - loss: 0.6086
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7176 - loss: 0.6520
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.7678 - loss: 0.5832
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7513 - loss: 0.6080
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7754 - loss: 0.5708
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.8105 - loss: 0.4716
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7692 - loss: 0.5697
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7420 - loss: 0.6029
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.7937 - loss: 0.5132
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.7974 - loss: 0.5098
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.8005 - loss: 0.5146
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.8054 - loss: 0.5233
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.7987 - loss: 0.4854
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.7659 - loss: 0.5963
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.7993 - loss: 0.5032
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.7998 - loss: 0.5149
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.8057 - loss: 0.5045
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7656 - loss: 0.5790
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.7973 - loss: 0.5482
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.7939 - loss: 0.5279
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8500 - loss: 0.4807

# %%
test_loss, test_accuracy = final_efficient.evaluate(test_images, test_labels, batch_size=32)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6182 - loss: 1.0125
# Test Loss: 0.9879275560379028, Test Accuracy: 0.625

# %%
history = final_inception.fit(
    train_images,
    train_labels,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9694 - loss: 0.0746
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9486 - loss: 0.1096
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9260 - loss: 0.1844
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9196 - loss: 0.2268
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9861 - loss: 0.0930
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9797 - loss: 0.0629
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9915 - loss: 0.0177
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9880 - loss: 0.0222
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9837 - loss: 0.0656
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9856 - loss: 0.0619
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9761 - loss: 0.0897
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9902 - loss: 0.0425
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.9976 - loss: 0.0130
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9993 - loss: 0.0028
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9905 - loss: 0.0221
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9998 - loss: 0.0024
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 1.0000 - loss: 0.0112
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9924 - loss: 0.0167
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9881 - loss: 0.0319
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9894 - loss: 0.0302
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9932 - loss: 0.0178
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.9338 - loss: 0.2765
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.9916 - loss: 0.0539
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.9905 - loss: 0.0330
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9783 - loss: 0.0549
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9811 - loss: 0.0532
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9780 - loss: 0.0894
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9717 - loss: 0.0828
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.9779 - loss: 0.0600

# %%
import numpy as np

# Predict the test data
y_pred = final_efficient.predict(test_images)

# Convert predictions and true labels to their respective classes
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicted class
y_true_classes = np.argmax(test_labels, axis=1)  # True class
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 766ms/step

# %%
from sklearn.metrics import classification_report

# Generate the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 1       0.56      0.96      0.71        50
#      Class 2       0.70      0.32      0.44        50
#      Class 3       0.70      0.46      0.55        50
#      Class 4       0.66      0.76      0.70        50
#
#     accuracy                           0.62       200
#    macro avg       0.65      0.62      0.60       200
# weighted avg       0.65      0.62      0.60       200

# %%
final_efficient.save("efficient.h5")

# %% [markdown]
# # Xception

# %%
from tensorflow.keras.applications.xception import Xception
image_size = 128

# %%
xception = Xception(weights="imagenet", include_top=False, input_shape=(image_size, image_size, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
for layer in xception.layers:
    layer.trainable = True

# %%
flat = layers.Flatten()(xception.output)
dense1 = layers.Dense(2048, activation="relu")(flat)
dropout1 = layers.Dropout(0.4)(dense1)
dense2 = layers.Dense(2048, activation="relu")(dropout1)
dropout2 = layers.Dropout(0.4)(dense2)
output = layers.Dense(4, activation="softmax")(dropout2)

# %%
final_xception = tf.keras.models.Model(inputs=[xception.input], outputs=[output])

# %%
final_xception.compile(optimizer=SGD(learning_rate=3e-4, momentum=0.9),
              loss="categorical_crossentropy",
              metrics=['accuracy'])

# %%
history = final_xception.fit(
    train_generator,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.7601 - loss: 0.6227
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.7394 - loss: 0.6231
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.7448 - loss: 0.6082
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.7554 - loss: 0.6166
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.7467 - loss: 0.6638
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.7822 - loss: 0.5520
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.7706 - loss: 0.5573
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.7614 - loss: 0.5839
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8043 - loss: 0.5351
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.7966 - loss: 0.4903
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.7814 - loss: 0.5190
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8030 - loss: 0.5101
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8050 - loss: 0.5235
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.7903 - loss: 0.4996
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8349 - loss: 0.4695
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.7966 - loss: 0.4987
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8077 - loss: 0.4496
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8149 - loss: 0.4755
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.8328 - loss: 0.4500
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8199 - loss: 0.4761
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8158 - loss: 0.4613
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8059 - loss: 0.4734
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8365 - loss: 0.3999
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8368 - loss: 0.4320
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8235 - loss: 0.4688
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8202 - loss: 0.4630
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8516 - loss: 0.3891
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.8303 - loss: 0.4611
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8496 - loss: 0.3815
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8634 - loss: 0.4035

# %%
test_loss, test_accuracy = final_xception.evaluate(test_images, test_labels, batch_size=32)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6744 - loss: 1.3117
# Test Loss: 1.1352989673614502, Test Accuracy: 0.7149999737739563

# %%
history = final_xception.fit(
    train_images,
    train_labels,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 29s 702ms/step - accuracy: 0.8537 - loss: 0.4473
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.8642 - loss: 0.3501
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.9183 - loss: 0.2520
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9278 - loss: 0.2108
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9402 - loss: 0.1898
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9420 - loss: 0.1851
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9511 - loss: 0.1452
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9711 - loss: 0.1357
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.9656 - loss: 0.1205
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9816 - loss: 0.0809
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9825 - loss: 0.0678
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9826 - loss: 0.0636
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9744 - loss: 0.0989
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9864 - loss: 0.0592
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.9893 - loss: 0.0538
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.9841 - loss: 0.0575
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9901 - loss: 0.0463
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9912 - loss: 0.0463
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9989 - loss: 0.0195
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9922 - loss: 0.0356
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 1.0000 - loss: 0.0234
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9880 - loss: 0.0295
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.9896 - loss: 0.0395
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9897 - loss: 0.0354
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9959 - loss: 0.0218
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9972 - loss: 0.0209
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9986 - loss: 0.0204
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9976 - loss: 0.0194
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 1.0000 - loss: 0.0109
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9982 - loss: 0.0162

# %%
final_xception.save("xception.h5")

# %%
import numpy as np

# Predict the test data
y_pred = final_xception.predict(test_images)

# Convert predictions and true labels to their respective classes
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicted class
y_true_classes = np.argmax(test_labels, axis=1)  # True class
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 356ms/step

# %%
from sklearn.metrics import classification_report

# Generate the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 1       0.88      0.84      0.86        50
#      Class 2       0.61      0.82      0.70        50
#      Class 3       0.83      0.40      0.54        50
#      Class 4       0.66      0.80      0.72        50
#
#     accuracy                           0.71       200
#    macro avg       0.74      0.72      0.70       200
# weighted avg       0.74      0.71      0.70       200

# %% [markdown]
# # Self Net

# %%
from tensorflow.keras import models

# %%
from tensorflow.keras import optimizers

from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import callbacks

from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications import InceptionResNetV2

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from sklearn.metrics import matthews_corrcoef, cohen_kappa_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

print("All Libraries Imported Successfully")
# Out:
# All Libraries Imported Successfully

# %%
input_layer = layers.Input(shape=(128,128, 3))

x = layers.Conv2D(
    filters=32,
    kernel_size=(3,3),
    strides=2,
    padding="same"
)(input_layer)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(rate=0.2)(x)

x = layers.Conv2D(
    64,
    3,
    strides=2,
    padding="same"
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(rate=0.2)(x)

x = layers.Conv2D(
    128,
    3,
    strides=2,
    padding="same"
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(rate=0.2)(x)

x = layers.Conv2D(
    256,
    3,
    strides=2,
    padding="same"
)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(rate=0.2)(x)

x = layers.Flatten()(x)

x = layers.Dense(units=100)(x)
x = layers.BatchNormalization(momentum=0.9)(x)
x = layers.LeakyReLU(0.2)(x)
x = layers.Dropout(rate=0.2)(x)

output_layer = layers.Dense(units=4, activation="softmax")(x)

model1 = models.Model(input_layer, output_layer)

# %%
opt = optimizers.Adam(learning_rate=0.0005)
model1.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

# %%
history = model1.fit(
    train_generator,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.7095 - loss: 0.7366
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.7067 - loss: 0.7413
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.7140 - loss: 0.7768
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.6938 - loss: 0.7688
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.7319 - loss: 0.7053
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7081 - loss: 0.7308
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.7022 - loss: 0.6980
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.7278 - loss: 0.7127
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.7426 - loss: 0.6978
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.7357 - loss: 0.6903
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.7151 - loss: 0.7235
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7447 - loss: 0.6635
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.6833 - loss: 0.7399
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7074 - loss: 0.7034
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7394 - loss: 0.6471
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7180 - loss: 0.6945
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.7455 - loss: 0.7021
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.6846 - loss: 0.7028
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.7257 - loss: 0.6887
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.6821 - loss: 0.7394
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7021 - loss: 0.7195
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7155 - loss: 0.7058
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.7210 - loss: 0.7102
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7267 - loss: 0.7063
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7269 - loss: 0.6384
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7527 - loss: 0.6179
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.7588 - loss: 0.6045
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.7296 - loss: 0.6925
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.7150 - loss: 0.6930
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.7176 - loss: 0.7021

# %%
test_loss, test_accuracy = model1.evaluate(test_images, test_labels, batch_size=32)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7066 - loss: 1.3221
# Test Loss: 1.3034765720367432, Test Accuracy: 0.7250000238418579

# %%
history = model1.fit(
    train_images,
    train_labels,
    batch_size=32,
    epochs=30,
    shuffle=True
)
# Out:
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9929 - loss: 0.0136
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9940 - loss: 0.0128
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9921 - loss: 0.0190
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9933 - loss: 0.0145
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9922 - loss: 0.0175
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9959 - loss: 0.0104
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9978 - loss: 0.0108
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9922 - loss: 0.0156
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9942 - loss: 0.0183
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9953 - loss: 0.0106
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9935 - loss: 0.0215
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9958 - loss: 0.0060
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9979 - loss: 0.0050
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9953 - loss: 0.0135
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9989 - loss: 0.0046
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9991 - loss: 0.0045
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9959 - loss: 0.0107
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9959 - loss: 0.0064
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0010

# %%
model1.save("Self_model1.h5")

# %%
import numpy as np

# Predict the test data
y_pred = model1.predict(test_images)

# Convert predictions and true labels to their respective classes
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicted class
y_true_classes = np.argmax(test_labels, axis=1)  # True class
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step

# %%
from sklearn.metrics import classification_report

# Generate the classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=['Class 1', 'Class 2', 'Class 3', 'Class 4'])
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#      Class 1       0.73      0.80      0.76        50
#      Class 2       0.72      0.68      0.70        50
#      Class 3       1.00      0.54      0.70        50
#      Class 4       0.59      0.84      0.69        50
#
#     accuracy                           0.71       200
#    macro avg       0.76      0.71      0.71       200
# weighted avg       0.76      0.71      0.71       200

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import numpy as np

# Callbacks to optimize training
lr_reduction = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, verbose=1, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)

# Compile your existing model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(
    train_images, train_labels,
    epochs=50,
    validation_data=(test_images,test_labels),
    callbacks=[lr_reduction]
)
# Out:
# Epoch 1/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.8036 - loss: 0.5698 - val_accuracy: 0.6250 - val_loss: 0.9996 - learning_rate: 0.0010
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7911 - loss: 0.4652 - val_accuracy: 0.6200 - val_loss: 0.9784 - learning_rate: 0.0010
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8079 - loss: 0.5008 - val_accuracy: 0.5750 - val_loss: 1.1265 - learning_rate: 0.0010
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7815 - loss: 0.5100 - val_accuracy: 0.6700 - val_loss: 0.9186 - learning_rate: 0.0010
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8276 - loss: 0.4520 - val_accuracy: 0.6450 - val_loss: 1.0637 - learning_rate: 0.0010
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8361 - loss: 0.4169 - val_accuracy: 0.7100 - val_loss: 0.8648 - learning_rate: 0.0010
# Epoch 7/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8291 - loss: 0.3976 - val_accuracy: 0.7150 - val_loss: 0.8343 - learning_rate: 0.0010
# Epoch 8/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8413 - loss: 0.4073 - val_accuracy: 0.7000 - val_loss: 0.9188 - learning_rate: 0.0010
# Epoch 9/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8379 - loss: 0.3642 - val_accuracy: 0.6700 - val_loss: 1.0177 - learning_rate: 0.0010
# Epoch 10/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8864 - loss: 0.3283
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8856 - loss: 0.3287 - val_accuracy: 0.6700 - val_loss: 0.9259 - learning_rate: 0.0010
# Epoch 11/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8467 - loss: 0.3322 - val_accuracy: 0.7050 - val_loss: 0.8675 - learning_rate: 2.0000e-04
# Epoch 12/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9067 - loss: 0.2707 - val_accuracy: 0.7100 - val_loss: 0.8644 - learning_rate: 2.0000e-04
# Epoch 13/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9081 - loss: 0.2516
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9080 - loss: 0.2514 - val_accuracy: 0.7150 - val_loss: 0.8505 - learning_rate: 2.0000e-04
# Epoch 14/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9135 - loss: 0.2412 - val_accuracy: 0.7050 - val_loss: 0.8521 - learning_rate: 4.0000e-05
# Epoch 15/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9126 - loss: 0.2290 - val_accuracy: 0.7050 - val_loss: 0.8530 - learning_rate: 4.0000e-05
# Epoch 16/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8993 - loss: 0.2508
# Epoch 16: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8999 - loss: 0.2501 - val_accuracy: 0.7050 - val_loss: 0.8607 - learning_rate: 4.0000e-05
# Epoch 17/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9249 - loss: 0.2224 - val_accuracy: 0.7050 - val_loss: 0.8613 - learning_rate: 8.0000e-06
# Epoch 18/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9151 - loss: 0.2466 - val_accuracy: 0.7050 - val_loss: 0.8597 - learning_rate: 8.0000e-06
# Epoch 19/50
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9123 - loss: 0.2559
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9132 - loss: 0.2532 - val_accuracy: 0.7050 - val_loss: 0.8619 - learning_rate: 8.0000e-06
# Epoch 20/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9038 - loss: 0.2429 - val_accuracy: 0.7050 - val_loss: 0.8615 - learning_rate: 1.6000e-06
# Epoch 21/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9432 - loss: 0.2184 - val_accuracy: 0.7050 - val_loss: 0.8616 - learning_rate: 1.6000e-06
# Epoch 22/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9031 - loss: 0.2247
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-06.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9035 - loss: 0.2250 - val_accuracy: 0.7050 - val_loss: 0.8611 - learning_rate: 1.6000e-06
# Epoch 23/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8991 - loss: 0.2672 - val_accuracy: 0.7050 - val_loss: 0.8612 - learning_rate: 1.0000e-06
# Epoch 24/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9139 - loss: 0.2329 - val_accuracy: 0.7050 - val_loss: 0.8612 - learning_rate: 1.0000e-06
# Epoch 25/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9217 - loss: 0.2167 - val_accuracy: 0.7050 - val_loss: 0.8613 - learning_rate: 1.0000e-06
# Epoch 26/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9178 - loss: 0.2304 - val_accuracy: 0.7050 - val_loss: 0.8615 - learning_rate: 1.0000e-06
# Epoch 27/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9161 - loss: 0.2099 - val_accuracy: 0.7050 - val_loss: 0.8615 - learning_rate: 1.0000e-06
# Epoch 28/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9166 - loss: 0.2300 - val_accuracy: 0.7050 - val_loss: 0.8613 - learning_rate: 1.0000e-06
# Epoch 29/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9311 - loss: 0.2134 - val_accuracy: 0.7050 - val_loss: 0.8615 - learning_rate: 1.0000e-06
# Epoch 30/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9254 - loss: 0.1950 - val_accuracy: 0.7050 - val_loss: 0.8615 - learning_rate: 1.0000e-06
# Epoch 31/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9257 - loss: 0.2249 - val_accuracy: 0.7050 - val_loss: 0.8616 - learning_rate: 1.0000e-06
# Epoch 32/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9027 - loss: 0.2432 - val_accuracy: 0.7050 - val_loss: 0.8616 - learning_rate: 1.0000e-06
# Epoch 33/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9168 - loss: 0.2361 - val_accuracy: 0.7050 - val_loss: 0.8619 - learning_rate: 1.0000e-06
# Epoch 34/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9070 - loss: 0.2515 - val_accuracy: 0.7050 - val_loss: 0.8623 - learning_rate: 1.0000e-06
# Epoch 35/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9202 - loss: 0.2276 - val_accuracy: 0.7050 - val_loss: 0.8625 - learning_rate: 1.0000e-06
# Epoch 36/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9190 - loss: 0.2252 - val_accuracy: 0.7050 - val_loss: 0.8627 - learning_rate: 1.0000e-06
# Epoch 37/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9307 - loss: 0.2091 - val_accuracy: 0.7050 - val_loss: 0.8628 - learning_rate: 1.0000e-06
# Epoch 38/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9262 - loss: 0.2606 - val_accuracy: 0.7050 - val_loss: 0.8631 - learning_rate: 1.0000e-06
# Epoch 39/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9102 - loss: 0.2268 - val_accuracy: 0.7050 - val_loss: 0.8632 - learning_rate: 1.0000e-06
# Epoch 40/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9121 - loss: 0.2631 - val_accuracy: 0.7050 - val_loss: 0.8628 - learning_rate: 1.0000e-06
# Epoch 41/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9323 - loss: 0.2077 - val_accuracy: 0.7050 - val_loss: 0.8628 - learning_rate: 1.0000e-06
# Epoch 42/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9249 - loss: 0.2144 - val_accuracy: 0.7050 - val_loss: 0.8628 - learning_rate: 1.0000e-06
# Epoch 43/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9173 - loss: 0.2477 - val_accuracy: 0.7050 - val_loss: 0.8627 - learning_rate: 1.0000e-06
# Epoch 44/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9401 - loss: 0.2043 - val_accuracy: 0.7050 - val_loss: 0.8626 - learning_rate: 1.0000e-06
# Epoch 45/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9120 - loss: 0.2293 - val_accuracy: 0.7050 - val_loss: 0.8627 - learning_rate: 1.0000e-06
# Epoch 46/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9129 - loss: 0.2597 - val_accuracy: 0.7050 - val_loss: 0.8626 - learning_rate: 1.0000e-06
# Epoch 47/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9279 - loss: 0.2150 - val_accuracy: 0.7050 - val_loss: 0.8628 - learning_rate: 1.0000e-06
# Epoch 48/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9053 - loss: 0.2287 - val_accuracy: 0.7050 - val_loss: 0.8626 - learning_rate: 1.0000e-06
# Epoch 49/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9325 - loss: 0.2099 - val_accuracy: 0.7050 - val_loss: 0.8628 - learning_rate: 1.0000e-06
# Epoch 50/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9339 - loss: 0.2124 - val_accuracy: 0.7050 - val_loss: 0.8628 - learning_rate: 1.0000e-06

# %%
epochs = range(1, len(history.history['accuracy']) + 1)

plt.figure(figsize=(12, 6))

# Accuracy plot
plt.plot(epochs, history.history['accuracy'], label='Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
import numpy as np

# Predict the test data
y_pred = model.predict(test_images)

# Convert predictions and true labels to their respective classes
y_pred_classes = np.argmax(y_pred, axis=1)  # Predicted class
y_true_classes = np.argmax(test_labels, axis=1)  # True class
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %%
import matplotlib.pyplot as plt

# Invert CLASS_MAPPING to get label-to-class mapping
CLASS_MAPPING = {'A': 0, 'D': 1, 'N': 2, 'G': 3}
LABEL_MAPPING = {v: k for k, v in CLASS_MAPPING.items()}

# Select 5 random images from the test dataset
indices = np.random.choice(len(test_images), 5, replace=False)

# Plot the images with actual and predicted labels
plt.figure(figsize=(15, 10))
for i, idx in enumerate(indices):
    image = test_images[idx]
    actual_label = LABEL_MAPPING[np.argmax(test_labels[idx])]
    predicted_label = LABEL_MAPPING[np.argmax(y_pred[idx])]

    plt.subplot(1, 5, i + 1)
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"Actual: {actual_label}\nPredicted: {predicted_label}")

plt.tight_layout()
plt.show()
