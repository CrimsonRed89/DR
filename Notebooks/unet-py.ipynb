# %%
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow.keras.backend as K
from keras.metrics import MeanIoU
import os
import numpy as np
from sklearn.model_selection import train_test_split
from PIL import Image, ImageOps
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization, MaxPooling2D, Dropout, UpSampling2D, concatenate, Activation, multiply, Reshape,BatchNormalization
from keras.layers import GlobalAveragePooling2D, Reshape
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler,EarlyStopping
# Out:
# 2024-12-24 13:28:16.994500: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-24 13:28:16.994635: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-24 13:28:17.121305: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_data(image_filenames, mask_filenames, image_dir, mask_dir, image_size=(512, 512)):
    image_list, mask_list = [], []
    for img_file, mask_file in zip(image_filenames, mask_filenames):
        if img_file.endswith(".png") and mask_file.endswith(".png"):
            image = cv2.imread(os.path.join(image_dir, img_file), cv2.IMREAD_GRAYSCALE)
            image = cv2.resize(image, image_size)
            image = image / 255.0  # Normalize to [0, 1]
            image = np.expand_dims(image, axis=-1)  # Add channel dimension
            image_list.append(image)
            
            mask = cv2.imread(os.path.join(mask_dir, mask_file), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, image_size)
            mask = mask / 255.0  # Normalize to [0, 1]
            mask = np.expand_dims(mask, axis=-1)  # Add channel dimension
            mask_list.append(mask)
    return np.array(image_list), np.array(mask_list)

# %%
# Define paths to your image and mask directories
image_dir = '/kaggle/input/fives-a-fundus-image/FIVES A Fundus Image Dataset for AI-based Vessel Segmentation/train/Original/'
mask_dir = '/kaggle/input/fives-a-fundus-image/FIVES A Fundus Image Dataset for AI-based Vessel Segmentation/train/Ground truth/'

# Get list of image and mask filenames
image_filenames = os.listdir(image_dir)
mask_filenames = os.listdir(mask_dir)

# Sort filenames to ensure corresponding images and masks match
image_filenames.sort()
mask_filenames.sort()
# Load images and masks
images, masks = load_data(image_filenames, mask_filenames, image_dir, mask_dir)

# %%
# Define paths to your image and mask directories
image_dir = '/kaggle/input/fives-a-fundus-image/FIVES A Fundus Image Dataset for AI-based Vessel Segmentation/test/Original/'
mask_dir = '/kaggle/input/fives-a-fundus-image/FIVES A Fundus Image Dataset for AI-based Vessel Segmentation/test/Ground truth/'

# Get list of image and mask filenames
image_filenames = os.listdir(image_dir)
mask_filenames = os.listdir(mask_dir)

# Sort filenames to ensure corresponding images and masks match
image_filenames.sort()
mask_filenames.sort()
# Load images and masks
Images_test, Masks_test = load_data(image_filenames, mask_filenames, image_dir, mask_dir)

# %%
images =np.array(images)
masks =np.array(masks)
Images_test =np.array(Images_test)
Masks_test =np.array(Masks_test)

images_val, images_test, masks_val, masks_test = train_test_split(Images_test, Masks_test, test_size=0.5, random_state=42)

# Print shapes to verify
print("Training images shape:", images.shape)
print("Training masks shape:", masks.shape)
print("test images shape:", images_test.shape)
print("test masks shape:", masks_test.shape)
print("validation images shape:", images_val.shape)
print("validation masks shape:", masks_val.shape)
# Ensure your images and masks are 4D tensors with consistent shapes

images = tf.expand_dims(images, axis=-1)  # If your images are (batch, height, width)
masks = tf.expand_dims(masks, axis=-1)    # If your masks are (batch, height, width)

images_test = tf.expand_dims(images_test, axis=-1)
masks_test = tf.expand_dims(masks_test, axis=-1)

images_val = tf.expand_dims(images_val, axis=-1)
masks_val = tf.expand_dims(masks_val, axis=-1)
# Out:
# Training images shape: (600, 512, 512, 1)
# Training masks shape: (600, 512, 512, 1)
# test images shape: (100, 512, 512, 1)
# test masks shape: (100, 512, 512, 1)
# validation images shape: (100, 512, 512, 1)
# validation masks shape: (100, 512, 512, 1)

# %%
def dice_loss(y_true, y_pred):
    smooth = 1.0  # To avoid division by zero
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return 1 - (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

# Define PSNR metric
def psnr(y_true, y_pred):
    # Ensure y_true and y_pred have the same shape
    y_true = tf.ensure_shape(y_true, y_pred.shape)
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

stop_callback=EarlyStopping(monitor='val_accuracy',restore_best_weights=True,verbose=1 , mode='max',patience=50,start_from_epoch=0)

# Custom SSIM metric
def ssim_metric(y_true, y_pred):
    return tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=1.0))

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout, Conv2DTranspose, BatchNormalization, Activation, Add
from tensorflow.keras.models import Model

# %%
def unet_model(input_shape=(512, 512, 1)):
    inputs = tf.keras.Input(input_shape)
    
    # Encoder
    c1 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)
    
    c2 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
    
    # Bottleneck
    c3 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    
    # Decoder
    u1 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c3)
    u1 = tf.keras.layers.concatenate([u1, c2])
    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u1)
    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c4)
    
    u2 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c4)
    u2 = tf.keras.layers.concatenate([u2, c1])
    c5 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u2)
    c5 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c5)
    
    outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c5)
    
    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
unet_model = unet_model((512,512,1))

# %%
print("Images shape:", images.shape)  # Should be (batch_size, 512, 512, 1)
print("Masks shape:", masks.shape)    # Should be (batch_size, 512, 512, 1)
# Out:
# Images shape: (600, 512, 512, 1, 1)
# Masks shape: (600, 512, 512, 1, 1)

# %%
# Ensure tensors have the correct shape by removing all unnecessary dimensions first
images = tf.squeeze(images)  # Removes all dimensions of size 1
masks = tf.squeeze(masks)
images_val = tf.squeeze(images_val)
masks_val = tf.squeeze(masks_val)
images_test = tf.squeeze(images_test)
masks_test = tf.squeeze(masks_test)

# Add back the single channel dimension to ensure (batch_size, 512, 512, 1)
images = tf.expand_dims(images, axis=-1)
masks = tf.expand_dims(masks, axis=-1)
images_val = tf.expand_dims(images_val, axis=-1)
masks_val = tf.expand_dims(masks_val, axis=-1)
images_test = tf.expand_dims(images_test, axis=-1)
masks_test = tf.expand_dims(masks_test, axis=-1)

# Verify the new shapes
print("Images shape:", images.shape)  # Should be (batch_size, 512, 512, 1)
print("Masks shape:", masks.shape)    # Should be (batch_size, 512, 512, 1)
# Out:
# Images shape: (600, 512, 512, 1)
# Masks shape: (600, 512, 512, 1)

# %%
unet_model.compile(optimizer='adam', loss='binary_crossentropy', 
              metrics=['accuracy', tf.keras.metrics.Precision(), MeanIoU(num_classes=2),dice_loss,ssim_metric,psnr])

# %%
history = unet_model.fit(images,masks,validation_data=(images_val,masks_val), epochs=50, batch_size=1, verbose = 1)
# Out:
# Epoch 1/50
# 2024-12-24 13:32:24.427586: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262144: 1.24674, expected 0.706489
# 2024-12-24 13:32:24.427643: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262145: 2.29621, expected 1.75596
# 2024-12-24 13:32:24.427652: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262146: 2.24082, expected 1.70057
# 2024-12-24 13:32:24.427661: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262147: 1.8087, expected 1.26845
# 2024-12-24 13:32:24.427669: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262148: 2.13502, expected 1.59477
# 2024-12-24 13:32:24.427676: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262149: 2.59674, expected 2.05649
# 2024-12-24 13:32:24.427684: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262150: 2.16053, expected 1.62028
# 2024-12-24 13:32:24.427692: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262151: 2.13737, expected 1.59712
# 2024-12-24 13:32:24.427700: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262152: 2.22161, expected 1.68136
# 2024-12-24 13:32:24.427708: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262153: 1.79817, expected 1.25791
# 2024-12-24 13:32:24.439300: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 13:32:24.439329: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 13:32:24.439338: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 13:32:24.439345: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 13:32:24.439352: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 13:32:24.439367: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-12-24 13:32:24.666646: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262144: 1.24674, expected 0.706489
# 2024-12-24 13:32:24.666704: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262145: 2.29621, expected 1.75596
# 2024-12-24 13:32:24.666714: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262146: 2.24082, expected 1.70057
# 2024-12-24 13:32:24.666722: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262147: 1.8087, expected 1.26845
# 2024-12-24 13:32:24.666730: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262148: 2.13502, expected 1.59477
# 2024-12-24 13:32:24.666738: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262149: 2.59674, expected 2.05649
# 2024-12-24 13:32:24.666746: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262150: 2.16053, expected 1.62028
# 2024-12-24 13:32:24.666773: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262151: 2.13737, expected 1.59712
# 2024-12-24 13:32:24.666789: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262152: 2.22161, expected 1.68136
# 2024-12-24 13:32:24.666811: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 262153: 1.79817, expected 1.25791
# 2024-12-24 13:32:24.678434: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 13:32:24.678470: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 13:32:24.678485: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 13:32:24.678497: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 13:32:24.678508: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 13:32:24.678529: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
#   3/600 ━━━━━━━━━━━━━━━━━━━━ 38s 64ms/step - accuracy: 0.6213 - dice_loss: 0.8733 - loss: 0.6364 - mean_io_u: 0.4650 - precision: 0.0964 - psnr: 6.6700 - ssim_metric: 0.0024
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1735047157.034158     117 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 59s 69ms/step - accuracy: 0.8249 - dice_loss: 0.9533 - loss: 155393.4844 - mean_io_u: 0.3256 - precision: 0.0847 - psnr: 9.4662 - ssim_metric: 0.3862 - val_accuracy: 0.9150 - val_dice_loss: 0.9999 - val_loss: 39584.0586 - val_mean_io_u: 0.4496 - val_precision: 1.2224e-04 - val_psnr: 11.4406 - val_ssim_metric: 0.7289
# Epoch 2/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.8434 - dice_loss: 0.9686 - loss: 91376.5156 - mean_io_u: 0.3325 - precision: 0.0834 - psnr: inf - ssim_metric: 0.5664 - val_accuracy: 0.9110 - val_dice_loss: 0.9997 - val_loss: 52308.0703 - val_mean_io_u: 0.4471 - val_precision: 9.6796e-04 - val_psnr: 11.1892 - val_ssim_metric: 0.7215
# Epoch 3/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.8394 - dice_loss: 0.9663 - loss: 44935.4492 - mean_io_u: 0.3266 - precision: 0.0727 - psnr: 9.1645 - ssim_metric: 0.5039 - val_accuracy: 0.9228 - val_dice_loss: 0.9999 - val_loss: 238284.8438 - val_mean_io_u: 0.4545 - val_precision: 0.0000e+00 - val_psnr: 11.9859 - val_ssim_metric: 0.7449
# Epoch 4/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.8509 - dice_loss: 0.9777 - loss: 191149.3438 - mean_io_u: 0.3388 - precision: 0.0859 - psnr: inf - ssim_metric: 0.6122 - val_accuracy: 0.9182 - val_dice_loss: 0.9991 - val_loss: 31410.5801 - val_mean_io_u: 0.4518 - val_precision: 0.0067 - val_psnr: 11.6586 - val_ssim_metric: 0.7263
# Epoch 5/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.8222 - dice_loss: nan - loss: nan - mean_io_u: 0.3204 - precision: 0.0877 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 6/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.9180 - dice_loss: nan - loss: nan - mean_io_u: 0.3846 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 7/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9176 - dice_loss: nan - loss: nan - mean_io_u: 0.3844 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 8/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9185 - dice_loss: nan - loss: nan - mean_io_u: 0.3853 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 9/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9182 - dice_loss: nan - loss: nan - mean_io_u: 0.3851 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 10/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9182 - dice_loss: nan - loss: nan - mean_io_u: 0.3849 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 11/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.9179 - dice_loss: nan - loss: nan - mean_io_u: 0.3848 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 12/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.9187 - dice_loss: nan - loss: nan - mean_io_u: 0.3856 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 13/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9182 - dice_loss: nan - loss: nan - mean_io_u: 0.3850 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 14/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9181 - dice_loss: nan - loss: nan - mean_io_u: 0.3849 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 15/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.9188 - dice_loss: nan - loss: nan - mean_io_u: 0.3854 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 16/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9172 - dice_loss: nan - loss: nan - mean_io_u: 0.3844 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 17/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.9178 - dice_loss: nan - loss: nan - mean_io_u: 0.3848 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 18/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.9185 - dice_loss: nan - loss: nan - mean_io_u: 0.3852 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 19/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.9193 - dice_loss: nan - loss: nan - mean_io_u: 0.3860 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 20/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 65ms/step - accuracy: 0.9178 - dice_loss: nan - loss: nan - mean_io_u: 0.3847 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 21/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9176 - dice_loss: nan - loss: nan - mean_io_u: 0.3849 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 22/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9198 - dice_loss: nan - loss: nan - mean_io_u: 0.3860 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 23/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9178 - dice_loss: nan - loss: nan - mean_io_u: 0.3846 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 24/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9186 - dice_loss: nan - loss: nan - mean_io_u: 0.3855 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 25/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9198 - dice_loss: nan - loss: nan - mean_io_u: 0.3859 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 26/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 38s 64ms/step - accuracy: 0.9184 - dice_loss: nan - loss: nan - mean_io_u: 0.3855 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 27/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9193 - dice_loss: nan - loss: nan - mean_io_u: 0.3856 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 28/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9176 - dice_loss: nan - loss: nan - mean_io_u: 0.3846 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 29/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9192 - dice_loss: nan - loss: nan - mean_io_u: 0.3860 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 30/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9191 - dice_loss: nan - loss: nan - mean_io_u: 0.3859 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 31/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 38s 64ms/step - accuracy: 0.9198 - dice_loss: nan - loss: nan - mean_io_u: 0.3857 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 32/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 38s 64ms/step - accuracy: 0.9190 - dice_loss: nan - loss: nan - mean_io_u: 0.3857 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 33/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9187 - dice_loss: nan - loss: nan - mean_io_u: 0.3851 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 34/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9171 - dice_loss: nan - loss: nan - mean_io_u: 0.3839 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 35/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9179 - dice_loss: nan - loss: nan - mean_io_u: 0.3848 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 36/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9179 - dice_loss: nan - loss: nan - mean_io_u: 0.3849 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 37/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9189 - dice_loss: nan - loss: nan - mean_io_u: 0.3859 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 38/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.9186 - dice_loss: nan - loss: nan - mean_io_u: 0.3852 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan - val_accuracy: 0.9237 - val_dice_loss: nan - val_loss: nan - val_mean_io_u: 0.4551 - val_precision: 0.0000e+00 - val_psnr: nan - val_ssim_metric: nan
# Epoch 39/50
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9182 - dice_loss: nan - loss: nan - mean_io_u: 0.3853 - precision: 0.0000e+00 - psnr: nan - ssim_metric: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 history = unet_model.fit(images,masks,validation_data=(images_val,masks_val), epochs=50, batch_size=1, verbose = 1)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:339, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     328 if getattr(self, "_eval_epoch_iterator", None) is None:
#     329     self._eval_epoch_iterator = TFEpochIterator(
#     330         x=val_x,
#     331         y=val_y,
#    (...)
#     337         shuffle=False,
#     338     )
# --> 339 val_logs = self.evaluate(
#     340     x=val_x,
#     341     y=val_y,
#     342     sample_weight=val_sample_weight,
#     343     batch_size=validation_batch_size or batch_size,
#     344     steps=validation_steps,
#     345     callbacks=callbacks,
#     346     return_dict=True,
#     347     _use_cached_eval_dataset=True,
#     348 )
#     349 val_logs = {
#     350     "val_" + name: val for name, val in val_logs.items()
#     351 }
#     352 epoch_logs.update(val_logs)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:425, in TensorFlowTrainer.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     423 for step, iterator in epoch_iterator.enumerate_epoch():
#     424     callbacks.on_test_batch_begin(step)
# --> 425     logs = self.test_function(iterator)
#     426     logs = self._pythonify_logs(logs)
#     427     callbacks.on_test_batch_end(step, logs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:877, in Function._call(self, *args, **kwds)
#     874 self._lock.release()
#     875 # In this case we have not created variables on the first call. So we can
#     876 # run the first trace but we should fail if variables are created.
# --> 877 results = tracing_compilation.call_function(
#     878     args, kwds, self._variable_creation_config
#     879 )
#     880 if self._created_variables:
#     881   raise ValueError("Creating variables on a non-first call to a function"
#     882                    " decorated with tf.function.")
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:138, in call_function(args, kwargs, tracing_options)
#     136 # Bind it ourselves to skip unnecessary canonicalization of default call.
#     137 bound_args = function.function_type.bind(*args, **kwargs)
# --> 138 flat_inputs = function.function_type.unpack_inputs(bound_args)
#     139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_type.py:391, in FunctionType.unpack_inputs(self, bound_parameters)
#     388 flat = []
#     389 for p in sorted_parameters:
#     390   flat.extend(
# --> 391       p.type_constraint.to_tensors(bound_parameters.arguments[p.name])
#     392   )
#     394 dealiased_inputs = []
#     395 ids_used = set()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:252, in TypeSpec.to_tensors(self, value)
#     249 """See TraceType base class for details. Do not override."""
#     251 tensors = []
# --> 252 nest.map_structure(
#     253     lambda spec, v: tensors.extend(spec.to_tensors(v)),
#     254     self._component_specs,
#     255     self._to_components(value))
#     256 return tensors
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/nest.py:631, in map_structure(func, *structure, **kwargs)
#     545 @tf_export("nest.map_structure")
#     546 def map_structure(func, *structure, **kwargs):
#     547   """Creates a new structure by applying `func` to each atom in `structure`.
#     548
#     549   Refer to [tf.nest](https://www.tensorflow.org/api_docs/python/tf/nest)
#    (...)
#     629     ValueError: If wrong keyword arguments are provided.
#     630   """
# --> 631   return nest_util.map_structure(
#     632       nest_util.Modality.CORE, func, *structure, **kwargs
#     633   )
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/nest_util.py:1066, in map_structure(modality, func, *structure, **kwargs)
#     969 """Creates a new structure by applying `func` to each atom in `structure`.
#     970
#     971 - For Modality.CORE: Refer to
#    (...)
#    1063   ValueError: If wrong keyword arguments are provided.
#    1064 """
#    1065 if modality == Modality.CORE:
# -> 1066   return _tf_core_map_structure(func, *structure, **kwargs)
#    1067 elif modality == Modality.DATA:
#    1068   return _tf_data_map_structure(func, *structure, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/nest_util.py:1104, in _tf_core_map_structure(func, *structure, **kwargs)
#    1101 flat_structure = (_tf_core_flatten(s, expand_composites) for s in structure)
#    1102 entries = zip(*flat_structure)
# -> 1104 return _tf_core_pack_sequence_as(
#    1105     structure[0],
#    1106     [func(*x) for x in entries],
#    1107     expand_composites=expand_composites,
#    1108 )
#
# KeyboardInterrupt:

# %%
unet_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', MeanIoU(num_classes=2)])  # Replace 'mean_io_u' with your actual IoU metric

# %%
test_loss, test_accuracy, test_miou = unet_model.evaluate(images_test, masks_test, verbose=1)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Mean IoU: {test_miou}")
# Out:
# 2024-12-24 13:58:10.972379: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:58:14.023551: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 1.79427, expected 0.794404
# 2024-12-24 13:58:14.023607: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 2.55447, expected 1.55461
# 2024-12-24 13:58:14.023623: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 2.37298, expected 1.37312
# 2024-12-24 13:58:14.023637: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 2.71847, expected 1.71861
# 2024-12-24 13:58:14.023649: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 2.55181, expected 1.55195
# 2024-12-24 13:58:14.023660: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 2.46424, expected 1.46438
# 2024-12-24 13:58:14.023670: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 2.83149, expected 1.83163
# 2024-12-24 13:58:14.023681: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 2.82969, expected 1.82983
# 2024-12-24 13:58:14.023692: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 2.273, expected 1.27314
# 2024-12-24 13:58:14.023703: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 2.03418, expected 1.03432
# 2024-12-24 13:58:14.397379: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 13:58:14.397443: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 13:58:14.397458: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 13:58:14.397471: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 13:58:14.397487: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 13:58:14.397510: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-12-24 13:58:14.397570: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.425316881s
# Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:58:16.681433: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:58:19.726100: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 1.79427, expected 0.794404
# 2024-12-24 13:58:19.726156: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 2.55447, expected 1.55461
# 2024-12-24 13:58:19.726165: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 2.37298, expected 1.37312
# 2024-12-24 13:58:19.726173: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 2.71847, expected 1.71861
# 2024-12-24 13:58:19.726181: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 2.55181, expected 1.55195
# 2024-12-24 13:58:19.726189: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 2.46424, expected 1.46438
# 2024-12-24 13:58:19.726197: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 2.83149, expected 1.83163
# 2024-12-24 13:58:19.726204: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 2.82969, expected 1.82983
# 2024-12-24 13:58:19.726212: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 2.273, expected 1.27314
# 2024-12-24 13:58:19.726220: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 2.03418, expected 1.03432
# 2024-12-24 13:58:20.097944: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 13:58:20.097996: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 13:58:20.098005: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 13:58:20.098013: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 13:58:20.098020: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 13:58:20.098037: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-12-24 13:58:20.098075: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 4.416851964s
# Trying algorithm eng15{k5=1,k6=0,k7=1,k10=1} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:58:27.847476: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,512,512]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:58:27.956791: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.109407401s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,512,512]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:58:33.508594: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,512,512]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:58:33.618007: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.109512918s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,512,512]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:11.784800: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=4,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,256,256]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:11.845528: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.060910911s
# Trying algorithm eng11{k2=4,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,256,256]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:12.845794: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,256,256]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:12.920615: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.075004874s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,256,256]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:19.638575: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=4,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,256,256]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:19.698740: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.060348944s
# Trying algorithm eng11{k2=4,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,256,256]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:20.698954: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,256,256]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:20.773826: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.074997169s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,128,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,256,256]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:31.129104: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=4,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:31.194643: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.065642703s
# Trying algorithm eng11{k2=4,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:32.194864: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=2,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:32.273034: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.078268529s
# Trying algorithm eng35{k2=2,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:33.273210: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:34.436087: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.162971499s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:41.519584: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=4,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:41.585159: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.065676325s
# Trying algorithm eng11{k2=4,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:42.585393: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng35{k2=2,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:42.663227: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.077940385s
# Trying algorithm eng35{k2=2,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:43.663397: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-12-24 13:59:44.825949: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.16264245s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,512,512]{3,2,1,0}, f32[64,128,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.9189 - loss: nan - mean_io_u_1: 0.4625
# 2024-12-24 13:59:49.038148: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 0.925107, expected 0.534345
# 2024-12-24 13:59:49.038209: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 1.48528, expected 1.09452
# 2024-12-24 13:59:49.038219: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 1.1634, expected 0.772635
# 2024-12-24 13:59:49.038228: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 1.71021, expected 1.31945
# 2024-12-24 13:59:49.038236: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 1.49143, expected 1.10067
# 2024-12-24 13:59:49.038244: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 1.15516, expected 0.764399
# 2024-12-24 13:59:49.038251: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 1.81655, expected 1.42579
# 2024-12-24 13:59:49.038259: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 1.83284, expected 1.44208
# 2024-12-24 13:59:49.038267: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 1.18872, expected 0.797957
# 2024-12-24 13:59:49.038275: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 1.28963, expected 0.898872
# 2024-12-24 13:59:49.086083: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=3,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 13:59:49.086141: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 13:59:49.086151: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 13:59:49.086159: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 13:59:49.086166: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 13:59:49.086184: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-12-24 13:59:49.774966: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 0.925107, expected 0.534345
# 2024-12-24 13:59:49.775019: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 1.48528, expected 1.09452
# 2024-12-24 13:59:49.775029: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 1.1634, expected 0.772635
# 2024-12-24 13:59:49.775037: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 1.71021, expected 1.31945
# 2024-12-24 13:59:49.775045: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 1.49143, expected 1.10067
# 2024-12-24 13:59:49.775053: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 1.15516, expected 0.764399
# 2024-12-24 13:59:49.775061: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 1.81655, expected 1.42579
# 2024-12-24 13:59:49.775069: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 1.83284, expected 1.44208
# 2024-12-24 13:59:49.775077: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 1.18872, expected 0.797957
# 2024-12-24 13:59:49.775085: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 1.28963, expected 0.898872
# 2024-12-24 13:59:49.822337: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1,512,512]{3,2,1,0}, f32[64,1,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=3,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-12-24 13:59:49.822380: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-12-24 13:59:49.822389: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-12-24 13:59:49.822396: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12060 (560.35.3)
# 2024-12-24 13:59:49.822403: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-12-24 13:59:49.822418: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 117s 6s/step - accuracy: 0.9195 - loss: nan - mean_io_u_1: 0.4588
# Test Loss: nan
# Test Accuracy: 0.9203264117240906
# Mean IoU: 0.45329636335372925

# %%
unet_model.save("Unet_segmentation_model.h5")

# %%
unet_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 512, 512,  │        640 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 512, 512,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 256, 256,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 256, 256,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 256, 256,  │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 128, 128,  │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 128,  │    590,080 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 256, 256,  │    131,200 │ conv2d_5[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 256, 256,  │    295,040 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 256, 256,  │    147,584 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 512, 512,  │     32,832 │ conv2d_7[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 512, 512,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 512, 512,  │     73,792 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 512, 512,  │     36,928 │ conv2d_8[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 512, 512,  │         65 │ conv2d_9[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,861,697 (7.10 MB)
#  Trainable params: 1,861,697 (7.10 MB)
#  Non-trainable params: 0 (0.00 B)
